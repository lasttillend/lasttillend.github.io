# %% [markdown]
# # Machine Learning Foundations Homework 1

# %% [markdown]
# Website of **Machine Learning Foundations** by Hsuan-Tien Lin: https://www.csie.ntu.edu.tw/~htlin/mooc/.

# %% [markdown]
# ## Question 1

# %% [markdown]
# Which of the following problems are best suited for machine learning?
#
# (i) Classifying numbers into primes and non-primes
#
# (ii) Detecting potential fraud in credit card charges
#
# (iii) Determining the time it would take a falling object to hit the ground
#
# (iv) Determining the optimal cycle for traffic lights in a busy intersection
#
# (v) Determining the age at which a particular medical test is recommended

# %% [markdown]
# ### Ans: (ii), (iv), (v)

# %% [markdown]
# ### Explanation

# %% [markdown]
# (i): False. Prime number has a programmable definition;
#
# (iii): False. The underlying pattern is known by the physical equation $h=\frac{1}{2}g t^2$.

# %% [markdown]
# ---
# For Question 2-5, identify the best type of learning that can be used to solve each task below.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Play chess better by practicing different strategies and receive outcomes as feedback

# %% [markdown]
# ### Ans: reinforcement learning

# %% [markdown]
# ### Explanation

# %% [markdown]
# We can make a reward or punishment to a single move. The machine can learn from these positive or negative feedbacks. So this is a type of reinforcement learning.

# %% [markdown]
# ## Question 3

# %% [markdown]
# Categorize books into groups without given topics

# %% [markdown]
# ### Ans: unsupervised learning

# %% [markdown]
# ### Explanation

# %% [markdown]
# We are not given labels at advance and need to let the machine classify books automatically. So this is a type of unsupervised learning.

# %% [markdown]
# ## Question 4

# %% [markdown]
# Recognize whether there is a face in the picture by a thousand face pictures and ten thousand non-face pictures.

# %% [markdown]
# ### Ans: supervised learning

# %% [markdown]
# ### Explanation

# %% [markdown]
# We are given the input and output labels together. So this is a type of a supervised learning.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Selectively schedule experiments on mice to quickly evaluate the potential of cancer medicines.

# %% [markdown]
# ### Ans: active learning

# %% [markdown]
# ### Explanation

# %% [markdown]
# We want to know the potential of one cancer medicine, so we perform appropriate experiments to get the answer. This is like a "question-asking" procress and hence is a type of an active learning.

# %% [markdown]
# ---
# Question 6-8 are about Off-Training-Set error.

# %% [markdown]
# Let $\mathcal{X} = \{\mathbf{x}_1, \mathbf{x}_2, \cdots, \mathbf{x}_N, \mathbf{x}_{N+1}, \cdots, \mathbf{x}_{N+L}\}$ and $\mathcal{Y} = \{-1, 1\}$ (binary classfication). Here the set of training examples is $\mathcal{D} = \{(\mathbf{x}_n, y_n)\}_{n=1}^{N}$, where $y_n \in \mathcal{Y}$, and the set of test inputs is $\{\mathbf{x}_{N+\ell}\}_{\ell=1}^L$. The off-Training-Set error (OTS) with respect to an underlying target $f$ and a hypothesis $g$ is

# %% [markdown]
# $$
# E_{O T S}(g, f)=\frac{1}{L} \sum_{\ell=1}^{L}\left[g\left(\mathbf{x}_{N +\ell}\right) \neq f\left(\mathbf{x}_{N + \ell}\right)\right].
# $$

# %% [markdown]
# ## Question 6

# %% [markdown]
# Consider $f(\mathbf{x}) = +1$ for all $\mathbf{x}$ and,
#
# $$g(\mathbf{x})=\left\{\begin{array}{lr}
# {+1,} & {\text { for } \mathbf{x}=\mathbf{x}_{k} \text { and } k \text { is odd and } 1 \leq k \leq N+L} \\
# {-1,} & {\text { otherwise. }}
# \end{array}\right.$$

# %% [markdown]
# What is $E_{O T S}(g, f)$ ?

# %% [markdown]
# ### Ans: $\frac{1}{L} (\left\lfloor\frac{N+L}{2}\right\rfloor -\left\lfloor\frac{N}{2}\right\rfloor)$

# %% [markdown]
# ### Explanation

# %% [markdown]
# The question is equivalent to count the even numbers between $N+1$ and $N+L$.

# %% [markdown]
# For example, if $N = 101$ and $L=19$, then training examples are from $1$ to $101$ and test examples are from $102$ to $120$. So there are 10 even numbers bewteen $102$ and $120$.

# %% [markdown]
# Now, calculate $\frac{N+L}{2} = 60$ and $\frac{N}{2}=50.5$. Thus, $10 =  \left\lfloor\frac{N+L}{2}\right\rfloor -\left\lfloor\frac{N}{2}\right\rfloor$.

# %% [markdown]
# By considering the 4 cases for the combination of $N$ (even/odd) and $L$ (even/odd), we can get the answer.

# %% [markdown]
# ## Question 7

# %% [markdown]
# We say that a target function $f$ can "generate" $\mathcal{D}$ in a noiseless setting if $f(\mathbf{x}_n) = y_n$ for all $(\mathbf{x}_n, y_n) \in \mathcal{D}$.
#
# For all possible $f: \mathcal{X} \rightarrow \mathcal{Y}$, how many of them can generate $\mathcal{D}$ in a noiseless setting?
#
# Note that we call two functions $f_1$ and $f_2$ the same if $f_1(\mathbf{x}) = f_2(\mathbf{x})$ for all $\mathbf{x} \in \mathcal{X}$.

# %% [markdown]
# ### Ans: $2^{L}$

# %% [markdown]
# ### Explanation

# %% [markdown]
# For a function $f$ to generate $\mathcal{D}$ in a noiseless setting, it must fit all the training data. So the only choice that such two functions can differ is on the test set. Since the size of the test set is $L$ and each label $y$ can only take two values, the total number of possible such functions is $2^L$.

# %% [markdown]
# ## Question 8

# %% [markdown]
# A deterministic algorithm $\mathcal{A}$ is defined as a procedure that takes $\mathcal{D}$ as an input, and outputs a hypothesis $g$. For any two deterministic algorithms $\mathcal{A}_1$ and $\mathcal{A}_2$, if all those $f$ that can "generate" $\mathcal{D}$ in a noiseless setting are equally likely in probability. Then which of the follow choices is correct?
#
# (i) For any given $f$ that "generates" $\mathcal{D}$,
# $$
# \left\{E_{O T S}\left(\mathcal{A}_{1}(\mathcal{D}), f\right)\right\}=\left\{E_{O T S}\left(\mathcal{A}_{2}(\mathcal{D}), f\right)\right\}
# $$
#
# (ii) For any given $f'$ that does not "generates" $\mathcal{D}$,
# $$
# \left\{E_{O T S}\left(\mathcal{A}_{1}(\mathcal{D}), f^{\prime}\right)\right\}=\left\{E_{O T S}\left(\mathcal{A}_{2}(\mathcal{D}), f^{\prime}\right)\right\}
# $$
#
# (iii)
# $$
# \mathbb{E}_{f}\left\{\operatorname{E}_{O T S}\left(\mathcal{A}_{1}(\mathcal{D}), f\right)\right\}=\mathbb{E}_{f}\left\{E_{O T S}\left(\mathcal{A}_{2}(\mathcal{D}), f\right)\right\}
# $$
#
# (iv)
# $$
# \mathbb{E}_{f}\left\{\operatorname{E}_{O T S}\left(\mathcal{A}_{1}(\mathcal{D}), f\right)\right\}=\mathbb{E}_{f}\left\{E_{O T S}(f, f)\right\}
# $$
#
# (v) none of the other choices

# %% [markdown]
# ### Ans: (iii)

# %% [markdown]
# ### Explanation

# %% [markdown]
# (i) and (ii): Two different algorithms will produce two different hypothises, so the result of the error on the test set may not be the same regardless $f$ "gerneates" $\mathcal{D}$ or not.
#
# (iv): $E_{O T S}(f, f)$ equals 0 and hence the RHS is 0, however, the LHS is not.

# %% [markdown]
# Now, we need to prove that
# $$
# \mathbb{E}_{f}\left\{\operatorname{E}_{O T S}(\mathcal{A}(\mathcal{D}), f)\right\}=\text { constant },
# $$
#
# regardless of $\mathcal{A}$.

# %% [markdown]
# **Proof:** For a given hypothesis $g$ and an integer $k$ between $0$ and $L$, we claim that there are ${L}\choose{k}$ of those $f$ in Question 7 that satisfy $E_{O T S}(g, f) = \frac{k}{L}$.

# %% [markdown]
# Proof of the claim:
#
# Since
# $$
# E_{O T S}(g, f) = \frac{1}{L}\sum_{\ell=1}^{L}\left[g\left(\mathbf{x}_{N +\ell}\right) \neq f\left(\mathbf{x}_{N + \ell}\right)\right]=\frac{k}{L},
# $$
#
# $f$ and $g$ differ on $k$ of those $\mathbf{x}_{N+\ell}$'s. Hence, the possible number of $f$ is ${L}\choose{k}$.

# %% [markdown]
# Now, we want to calculuate the expectation of off training-set error $\mathbb{E}_{f}\left\{E_{O T S}\left(g, f\right)\right\}$ for a fixed hypothesis $g$ and we will see it is a constant.

# %% [markdown]
# Since we are assuming all of $f$ are equally likely in probability, $E_{O T S}\left(g, f\right)$ is a discrete random variable (remember $g$ is fixed now) which has a distribution like:
#
# |  value   | $0$  | $\frac{1}{L}$ | $\frac{2}{L}$ |$\cdots$ | $\frac{k}{L}$ | $\cdots$ | $\frac{L-1}{L}$ | $1$ |
# |  :----  | :----:  |  :----:  | :----:  |  :----:  | :----:  |  :----:  | :----:  | :----: |
# | probability    | $\frac{{L}\choose{0}}{2^L}$  | $\frac{{L}\choose{1}}{2^L}$ | $\frac{{L}\choose{2}}{2^L}$ |$\cdots$ | $\frac{{L}\choose{k}}{2^L}$ | $\cdots$ | $\frac{{L}\choose{L-1}}{2^L}$ | $\frac{{L}\choose{L}}{2^L}$ |

# %% [markdown]
# Therefore,
#
# \begin{align}
# \mathbb{E}_{f}\left\{E_{O T S}\left(g, f\right)\right\}
# &= \sum_{k=0}^{L} \frac{{L}\choose{k}}{2^L} \cdot \frac{k}{L} \\
# &= \sum_{k=1}^{L} \frac{{{L-1}\choose{k-1}} \cdot L}{2^L} \cdot \frac{1}{L} \\
# &= \frac{1}{2^L} \sum_{k=1}^{L} {{L-1}\choose{k-1}} \\
# &= \frac{2^{L-1}}{2^L} \\
# &= \frac{1}{2}.
# \end{align}
#
# Here we use the equality $k {{L}\choose{k}} = {{L-1}\choose{k-1}}L$.

# %% [markdown]
# Finally, we proceed to prove the desired result:
# $$
# \mathbb{E}_{f}\left\{\operatorname{E}_{O T S}(\mathcal{A}(\mathcal{D}), f)\right\}=\text { constant },
# $$
#
# regardless of $\mathcal{A}$.

# %% [markdown]
# However, we have just proved that $\mathbb{E}_{f}\left\{\operatorname{E}_{O T S}(g, f)\right\}$ is a constant for any hypothesis $g$ and thus, the result holds.

# %% [markdown]
# ---

# %% [markdown]
# For Question 9-12, consider the bin model introduced in class.

# %% [markdown]
# ## Question 9

# %% [markdown]
# Consider a bin with infinitely man marbles, and let $\mu$ be the fraction of orange marbles in the bin, and $\nu$ is the fraction of orange marbles in a sample of 10 marbles.
#
# If $\mu=0.5$, what is the probability of $\nu=\mu$ ?

# %% [markdown]
# ### Ans: 0.2461

# %% [markdown]
# ### Explanation

# %%
def choose(n, k):
    """
    Returns the combination number n choose k.
    """
    from math import factorial
    return int(factorial(n) / (factorial(n-k) * factorial(k)))

# %%
n = 10
mu = 0.5
k = n * mu
prob_nu_eq_mu = choose(n, k) * (mu ** k) * (1 - mu) ** (n - k)
prob_nu_eq_mu
# Out:
# 0.24609375

# %% [markdown]
# Let $X$ be the number of orange marbles in the sample. Since the bin is assumed to have infinitely many marbles, we can treate $X$ as a sum of i.i.d Bernouli random variables $\text{Bernouli}(p)$ with success probability $p=\mu$. Then $X$ has a binomial distribution $\text{binomial}(10, 0.5)$.
#
# In the meanwhile, $\nu = 0.5 \iff X=5$,
#
# hence
# $$
# P(\nu=0.5) = P(X=5) = {{10}\choose{5}} \left(\frac{1}{2}\right)^5 \left(1-\frac{1}{2}\right)^{10-5} \approx 0.2461.
# $$

# %% [markdown]
# Here is what the distribution of $X$ looks like.

# %%
from scipy.stats import binom
import numpy as np
import matplotlib.pyplot as plt

n, p = 10, 0.5
xs = list(range(0, 11))
probs = [binom.pmf(x, n, p) for x in xs]

fig, ax = plt.subplots(1, 1)
ax.plot(xs, probs, 'bo', ms=8, label='binom pmf')
ax.vlines(xs, 0, probs, colors='b', lw=5, alpha=0.5);

# %%
rv = binom(n, p)
rv.pmf(5)   # Verify P(X=5)=0.2461
# Out:
# 0.24609375000000025

# %% [markdown]
# ## Question 10

# %% [markdown]
# If $\mu = 0.9$, what is the probability of $\nu=\mu$ ?

# %% [markdown]
# ### Ans: $P(\nu=0.9)= P(X=9)=0.3874$

# %%
mu = 0.9
k = n * mu
prob_nu_eq_mu = choose(n, k) * (mu ** k) * (1 - mu) ** (n - k)
prob_nu_eq_mu
# Out:
# 0.38742048900000003

# %%
p = 0.9
rv = binom(n, p)
rv.pmf(9)  # Verify P(X=9)
# Out:
# 0.38742048900000037

# %% [markdown]
# ## Question 11

# %% [markdown]
# If $\mu = 0.9$, what is the probability of $\nu \le 0.1$ ?

# %% [markdown]
# ## Ans: $P(\nu \le 0.1) = P(X \le 1)=9.0999\times 10^{-9}$

# %%
k = 0
prob_x_eq_0 = choose(n, k) * (mu ** k) * (1 - mu) ** (n - k)
k = 1
prob_x_eq_1 = choose(n, k) * (mu ** k) * (1 - mu) ** (n - k)
prob_nu_le_01 = prob_x_eq_0 + prob_x_eq_1
prob_nu_le_01
# Out:
# 9.09999999999998e-09

# %%
binom.pmf(0, n, p) + binom.pmf(1, n, p)
# Out:
# 9.099999999999995e-09

# %% [markdown]
# ## Question 12

# %% [markdown]
# If $\mu=0.9$, what is the bound given by Hoeffding's inequality for the probability $\nu \le 0.1$ ?

# %% [markdown]
# ### Ans: $5.52\times 10^{-6}$

# %% [markdown]
# ### Explanation

# %% [markdown]
# Recall Hoeffding's inequality:
#
# $$
# \mathbb{P}(|\nu-\mu|>\epsilon) \leq 2 \exp \left(-2 \epsilon^{2} N\right).
# $$

# %% [markdown]
# Substitute our data, we can get

# %% [markdown]
# \begin{align}
# \mathbb{P}\left(\nu \le 0.1\right) &= \mathbb{P}\left(\nu - 0.9 \le 0.1 - 0.9\right) \\
# &\le \mathbb{P}\left(\left| \nu - 0.9 \right| \ge 0.8 \right).
# \end{align}

# %% [markdown]
# Hence, we have $\epsilon=0.8$ here and the answer follows.

# %%
def hoeffding_ineq(epsilon, N):
    """
    Returns the bound by hoeffding's inequality.
    """
    from numpy import exp
    return 2 * exp(-2 * epsilon ** 2 * N)

# %%
hoeffding_ineq(0.8, 10)
# Out:
# 5.521545144074388e-06

# %% [markdown]
# ---

# %% [markdown]
# Question 13-14 illustate what happens with multiple bins using dice to indicate 6 bins. Please note that the dice is not meant to be thrown for random experiments in this problem. They are just used to bind the six faces together. The probability below only refers to drawing from the bag.

# %% [markdown]
# ## Question 13

# %% [markdown]
# Consider four kinds of dice in a bag, with the same (super large) quantity for each kind.
#
# A: all even numbers are colored orange, all odd numbers are colored green
#
# B: all even numbers are colored green, all odd numbers are colored orange
#
# C: all small(1-3) are colored orange, all large numbers(4-6) are colored green
#
# D: all small(1-3) are colored green, all large numbers(4-6) are colored orange
#
# If we pick 5 dice from the bag, what is the probability that we get five orange 1's?

# %% [markdown]
# ### Ans: $\frac{1}{32}$

# %% [markdown]
# ### Explanation

# %% [markdown]
# Notice that only dice B and C have orange 1, so the total probability of getting five orange 1's is $(\frac{1}{2})^5=\frac{1}{32}$.

# %% [markdown]
# ## Question 14

# %% [markdown]
# If we pick 5 dice from the bag, what is the probability that we get "some number" that is purely orange?

# %% [markdown]
# ### Ans: $\frac{31}{256}$

# %% [markdown]
# ### Explanation

# %% [markdown]
# Let $X_i$ be the total number of orange faces for number $i$ in 5 dice, $i=1, \cdots, 6$. We want to calculate the probability that at least one of $X_i$ is 5, i.e.,
#
# $$
# \mathbb{P} \left(\{X_1 = 5\} \cup \{X_2 = 5\} \cup \cdots \cup \{X_6 = 5\}\right).
# $$

# %% [markdown]
# Notice that number 1 and number 3 always take on the same color and so do 4 and 6. Meanwhile, we cannot see number 2 and 5 having the same color no matter what kind of dice we get, neither do 1 and 4.

# %% [markdown]
# Thus, we can simplify the above probability a bit by removing $X_3$ and $X_6$:
#
# $$
# \mathbb{P} \left(\{X_1 = 5\} \cup \{X_2 = 5\} \cup \{X_4 = 5\} \cup \{X_5 = 5\}\right).
# $$

# %% [markdown]
# We can use inclusion-exclusion principle to calculate the above probability. So we need probability for individual event, for intersection of two, three, and four events, respectively.

# %% [markdown]
# The probability of a single event is straightfoward: $\mathbb{P}(\{X_i=5\})=(\frac{1}{2})^5=\frac{1}{32}$.
#
# As for intersection of two events:
#
# - $\{X_1=5\}$ and $\{X_2=5\}$ can both occur if and only if all 5 dice are of type C;
# - $\{X_1=5\}$ and $\{X_4=5\}$ cannot both occur at the same time because 1 and 4 cannot have the same color;
# - $\{X_1=5\}$ and $\{X_5=5\}$ can both occur if and only if all 5 dice are of type B;
# - $\{X_2=5\}$ and $\{X_4=5\}$ can both occur if and only if all 5 dice are of type A;
# - $\{X_2=5\}$ and $\{X_5=5\}$ cannot both occur at the same time because 2 and 5 cannot have the same color;
# - $\{X_4=5\}$ and $\{X_5=5\}$ can both occur if and only if all 5 dice are of type D.
#
# The probability of each intersection is $(\frac{1}{4})^5=\frac{1}{1024}$.

# %% [markdown]
# As for intersection of three (or four), there are no three such events that can occur at the same time. Hence the probability is 0.

# %% [markdown]
# By inclusion-exclusion principle,
# $$
# \mathbb{P} \left(\{X_1 = 5\} \cup \{X_2 = 5\} \cup \{X_4 = 5\} \cup \{X_5 = 5\}\right)
# = 4 \cdot \frac{1}{32} - 4 \cdot \frac{1}{1024}
# = \frac{31}{256}.
# $$

# %% [markdown]
# ---

# %% [markdown]
# For Question 15-20, you will play with PLA and pocket algorithm. First, we use an artificial data set to study PLA. The data set is in `hw1_15_train.dat`.

# %% [markdown]
# ## Question 15

# %% [markdown]
# Each line of the data set contains one $(\mathbf{x}_n, y_n)$ with $\mathbf{x}_n \in \mathbb{R}^4$. The first 4 numbers of the line contains the components of $\mathbf{x}_n$ orderly, the last number is $y_n$.
#
# Please initialize your algorithm with $\mathbf{w}=0$ and take sign(0) as $-1$.
#
# Implement a version of PLA by visiting examples in the naive cycle using the order of examples in the data set. Run the algorithm on the data set. What is the number of updates before the algorithm halts?

# %%
import pandas as pd

# Load data
data = pd.read_csv('hw1_15_train.dat', sep='\s+', header=None, names=['x1', 'x2', 'x3', 'x4', 'y'])

# Construct features and labels
y = data['y'].to_numpy()
X = data[['x1', 'x2', 'x3', 'x4']].to_numpy()

# %%
# def PLA_cyclic(X, y):
#     """
#     PLA by visiting examples in the naive cycle using the order of examples in the data set (X, y).
    
#     Args:
#         X: numpy array(n, d), feature matrix
#         y: numpy array(n, ), labels
#     Returns:
#         w_t: numpy array(d+1, ), final weights including bias w0
#         t: the total number of updates 
#     """
    
#     n, d = X.shape
#     # Add a column of ones as first column
#     X = np.c_[np.ones((n, 1)), X]
    
#     # Initialize w to 0 and add an extra zero for w0
#     w_t = np.zeros(d+1)
    
#     # If we are lucky at the beginning that all of our data has label -1, 
#     # then we do not have to update anymore, just return w_t with 0 
#     # because it is already a feasible solution
#     if not still_can_find_mistakes(w_t, X, y):
#         return w_t, 0
#     else:
#         has_mistake = 1
        
#     # Count the number of updates
#     t = 0 
    
#     # We are sure that there exists at least one mistake in our data set 
#     # under the current weight w_t, so we do need to update
#     while has_mistake:
#         for x_t, y_t in zip(X, y):
#             if sign(w_t.T @ x_t) != y_t:  # Find a mistake
#                 w_t += y_t * x_t  # Correct the mistake
#                 t += 1
#                 if not still_can_find_mistakes(w_t, X, y):
#                     has_mistake = 0
#                     break
#     return w_t, t

                
# ######## Some helper functions ########
# def sign(x):
#     return 1 if x > 0 else -1

# def still_can_find_mistakes(w, X, y):
#     """
#     Returns True if there are mistakes in PLA using the current weight.
    
#     Args:
#         w: numpy array(d + 1, ) current weight
#         X: numpy array(n, d+1) feature matrix
#         y: numpy array(n, ) labels
#     """
#     res = False
#     for x_t, y_t in zip(X, y):
#         if sign(w.T @ x_t) != y_t:
#             res = True
#             break
#     return res

# %%
def PLA_cyclic(X, y):
    """
    PLA by visiting examples in the naive cycle using the order of examples in the data set (X, y).
    
    Args:
        X: numpy array(n, d), feature matrix
        y: numpy array(n, ), labels
    Returns:
        w         : numpy array(d+1, ), final weights including bias w0
        update_cnt: the total number of updates 
    """
    
    n, d = X.shape
    # Add a column of ones as first column
    X = np.c_[np.ones((n, 1)), X]
    
    # Initialize w to 0 and add an extra zero for w0
    w = np.zeros(d + 1)
        
    # Count the number of updates
    update_cnt = 0 
    
    is_finished = 0
    correct_num = 0
    t = 0

    while not is_finished:
        x_t, y_t = X[t], y[t]
        
        if sign(w.T @ x_t) == y_t:  # Correctly classify the current example
            correct_num += 1
        else:                       # Find a mistake
            w += y_t * x_t          # Correct the mistake
            update_cnt += 1         # Increment update count
            correct_num = 0         # Reset correct num to 0 to retest the new w
        if t == n - 1:              # Start the next cycle
            t = 0
        else:
            t += 1
        if correct_num == n:        # Have all examples classified correctly
            is_finished = 1
  
    return w, update_cnt

                
######## Some helper functions ########
def sign(x):
    return 1 if x > 0 else -1

# %%
w, t = PLA_cyclic(X, y)

# %%
w
# Out:
# array([-3.       ,  3.0841436, -1.583081 ,  2.391305 ,  4.5287635])

# %%
t
# Out:
# 45

# %% [markdown]
# So the total number of updates before the algorithm halts is 45 times under my implementation of PLA with naive cycling.

# %% [markdown]
# ## Question 16

# %% [markdown]
# Implement a version of PLA by visiting examples in fixed, pre-determined random cycles throughout the algorithm. Run the algorithm on the data set.
#
# Please repeat your experiment for 2000 times, each with a different random seed. What is the average number of updates before the algorithm halts?

# %%
def PLA_random(X, y):
    """
    PLA by visiting examples in a fixed, pre-determined random cycles.
    
    Note: it repeat experiment for 2000 times.
    seed.
    
    Args:
        X: numpy array(n, d), feature matrix
        y: numpy array(n, ), labels
    Returns:
        w         : numpy array(d+1, ), final weights including bias w0
        update_cnt: the average number of updates 
    """
    T = 2000
    t_list = []
    n = X.shape[0]
    indices = np.arange(n)
    
    for i in range(T):
        # Shuffle X and y together using random indices
        np.random.shuffle(indices)  
        X = X[indices]
        y = y[indices]
        w, t = PLA_cyclic(X, y)
        t_list.append(t)
        print(f"{i}th experiment: {t} updates!")
    return w, int(np.mean(t_list))

# %%
w, t = PLA_random(X, y)
# Out:
# 0th experiment: 58 updates!
# 1th experiment: 37 updates!
# 2th experiment: 35 updates!
# 3th experiment: 24 updates!
# 4th experiment: 39 updates!
# 5th experiment: 43 updates!
# 6th experiment: 37 updates!
# 7th experiment: 58 updates!
# 8th experiment: 37 updates!
# 9th experiment: 20 updates!
# 10th experiment: 45 updates!
# 11th experiment: 41 updates!
# 12th experiment: 35 updates!
# 13th experiment: 41 updates!
# 14th experiment: 33 updates!
# 15th experiment: 56 updates!
# 16th experiment: 47 updates!
# 17th experiment: 33 updates!
# 18th experiment: 37 updates!
# 19th experiment: 33 updates!
# 20th experiment: 56 updates!
# 21th experiment: 37 updates!
# 22th experiment: 41 updates!
# 23th experiment: 43 updates!
# 24th experiment: 28 updates!
# 25th experiment: 52 updates!
# 26th experiment: 22 updates!
# 27th experiment: 39 updates!
# 28th experiment: 31 updates!
# 29th experiment: 37 updates!
# 30th experiment: 43 updates!
# 31th experiment: 24 updates!
# 32th experiment: 66 updates!
# 33th experiment: 31 updates!
# 34th experiment: 43 updates!
# 35th experiment: 39 updates!
# 36th experiment: 35 updates!
# 37th experiment: 35 updates!
# 38th experiment: 50 updates!
# 39th experiment: 49 updates!
# 40th experiment: 18 updates!
# 41th experiment: 41 updates!
# 42th experiment: 37 updates!
# 43th experiment: 39 updates!
# 44th experiment: 39 updates!
# 45th experiment: 39 updates!
# 46th experiment: 41 updates!
# 47th experiment: 43 updates!
# 48th experiment: 37 updates!
# 49th experiment: 33 updates!
# 50th experiment: 24 updates!
# 51th experiment: 20 updates!
# 52th experiment: 60 updates!
# 53th experiment: 41 updates!
# 54th experiment: 56 updates!
# 55th experiment: 41 updates!
# 56th experiment: 37 updates!
# 57th experiment: 39 updates!
# 58th experiment: 52 updates!
# 59th experiment: 26 updates!
# 60th experiment: 22 updates!
# 61th experiment: 56 updates!
# 62th experiment: 35 updates!
# 63th experiment: 56 updates!
# 64th experiment: 41 updates!
# 65th experiment: 43 updates!
# 66th experiment: 41 updates!
# 67th experiment: 52 updates!
# 68th experiment: 43 updates!
# 69th experiment: 37 updates!
# 70th experiment: 58 updates!
# 71th experiment: 18 updates!
# 72th experiment: 60 updates!
# 73th experiment: 41 updates!
# 74th experiment: 48 updates!
# 75th experiment: 52 updates!
# 76th experiment: 41 updates!
# 77th experiment: 35 updates!
# 78th experiment: 22 updates!
# 79th experiment: 58 updates!
# 80th experiment: 45 updates!
# 81th experiment: 39 updates!
# 82th experiment: 62 updates!
# 83th experiment: 35 updates!
# 84th experiment: 45 updates!
# 85th experiment: 37 updates!
# 86th experiment: 54 updates!
# 87th experiment: 35 updates!
# 88th experiment: 20 updates!
# 89th experiment: 35 updates!
# 90th experiment: 18 updates!
# 91th experiment: 39 updates!
# 92th experiment: 26 updates!
# 93th experiment: 26 updates!
# 94th experiment: 52 updates!
# 95th experiment: 52 updates!
# 96th experiment: 54 updates!
# 97th experiment: 22 updates!
# 98th experiment: 62 updates!
# 99th experiment: 37 updates!
# 100th experiment: 39 updates!
# 101th experiment: 39 updates!
# 102th experiment: 37 updates!
# 103th experiment: 37 updates!
# 104th experiment: 41 updates!
# 105th experiment: 37 updates!
# 106th experiment: 39 updates!
# 107th experiment: 41 updates!
# 108th experiment: 22 updates!
# 109th experiment: 35 updates!
# 110th experiment: 37 updates!
# 111th experiment: 58 updates!
# 112th experiment: 54 updates!
# 113th experiment: 35 updates!
# 114th experiment: 39 updates!
# 115th experiment: 41 updates!
# 116th experiment: 37 updates!
# 117th experiment: 41 updates!
# 118th experiment: 39 updates!
# 119th experiment: 30 updates!
# 120th experiment: 39 updates!
# 121th experiment: 41 updates!
# 122th experiment: 33 updates!
# 123th experiment: 28 updates!
# 124th experiment: 37 updates!
# 125th experiment: 39 updates!
# 126th experiment: 33 updates!
# 127th experiment: 43 updates!
# 128th experiment: 39 updates!
# 129th experiment: 37 updates!
# 130th experiment: 64 updates!
# 131th experiment: 37 updates!
# 132th experiment: 39 updates!
# 133th experiment: 45 updates!
# 134th experiment: 35 updates!
# 135th experiment: 33 updates!
# 136th experiment: 37 updates!
# 137th experiment: 35 updates!
# 138th experiment: 52 updates!
# 139th experiment: 22 updates!
# 140th experiment: 45 updates!
# 141th experiment: 33 updates!
# 142th experiment: 37 updates!
# 143th experiment: 50 updates!
# 144th experiment: 54 updates!
# 145th experiment: 26 updates!
# 146th experiment: 60 updates!
# 147th experiment: 37 updates!
# 148th experiment: 31 updates!
# 149th experiment: 39 updates!
# 150th experiment: 45 updates!
# 151th experiment: 33 updates!
# 152th experiment: 45 updates!
# 153th experiment: 37 updates!
# 154th experiment: 39 updates!
# 155th experiment: 37 updates!
# 156th experiment: 41 updates!
# 157th experiment: 62 updates!
# 158th experiment: 24 updates!
# 159th experiment: 37 updates!
# 160th experiment: 66 updates!
# 161th experiment: 41 updates!
# 162th experiment: 37 updates!
# 163th experiment: 37 updates!
# 164th experiment: 49 updates!
# 165th experiment: 28 updates!
# 166th experiment: 39 updates!
# 167th experiment: 37 updates!
# 168th experiment: 18 updates!
# 169th experiment: 24 updates!
# 170th experiment: 18 updates!
# 171th experiment: 43 updates!
# 172th experiment: 37 updates!
# 173th experiment: 33 updates!
# 174th experiment: 39 updates!
# 175th experiment: 43 updates!
# 176th experiment: 43 updates!
# 177th experiment: 33 updates!
# 178th experiment: 52 updates!
# 179th experiment: 31 updates!
# 180th experiment: 41 updates!
# 181th experiment: 39 updates!
# 182th experiment: 31 updates!
# 183th experiment: 39 updates!
# 184th experiment: 39 updates!
# 185th experiment: 39 updates!
# 186th experiment: 35 updates!
# 187th experiment: 22 updates!
# 188th experiment: 41 updates!
# 189th experiment: 22 updates!
# 190th experiment: 62 updates!
# 191th experiment: 26 updates!
# 192th experiment: 43 updates!
# 193th experiment: 11 updates!
# 194th experiment: 37 updates!
# 195th experiment: 56 updates!
# 196th experiment: 28 updates!
# 197th experiment: 39 updates!
# 198th experiment: 31 updates!
# 199th experiment: 35 updates!
# 200th experiment: 41 updates!
# 201th experiment: 11 updates!
# 202th experiment: 60 updates!
# 203th experiment: 37 updates!
# 204th experiment: 66 updates!
# 205th experiment: 35 updates!
# 206th experiment: 62 updates!
# 207th experiment: 24 updates!
# 208th experiment: 39 updates!
# 209th experiment: 56 updates!
# 210th experiment: 33 updates!
# 211th experiment: 39 updates!
# 212th experiment: 20 updates!
# 213th experiment: 58 updates!
# 214th experiment: 54 updates!
# 215th experiment: 52 updates!
# 216th experiment: 37 updates!
# 217th experiment: 26 updates!
# 218th experiment: 60 updates!
# 219th experiment: 45 updates!
# 220th experiment: 60 updates!
# 221th experiment: 48 updates!
# 222th experiment: 24 updates!
# 223th experiment: 41 updates!
# 224th experiment: 37 updates!
# 225th experiment: 39 updates!
# 226th experiment: 35 updates!
# 227th experiment: 50 updates!
# 228th experiment: 54 updates!
# 229th experiment: 22 updates!
# 230th experiment: 54 updates!
# 231th experiment: 54 updates!
# 232th experiment: 35 updates!
# 233th experiment: 24 updates!
# 234th experiment: 39 updates!
# 235th experiment: 37 updates!
# 236th experiment: 39 updates!
# 237th experiment: 54 updates!
# 238th experiment: 45 updates!
# 239th experiment: 39 updates!
# 240th experiment: 60 updates!
# 241th experiment: 37 updates!
# 242th experiment: 26 updates!
# 243th experiment: 75 updates!
# 244th experiment: 43 updates!
# 245th experiment: 35 updates!
# 246th experiment: 24 updates!
# 247th experiment: 45 updates!
# 248th experiment: 37 updates!
# 249th experiment: 52 updates!
# 250th experiment: 37 updates!
# 251th experiment: 54 updates!
# 252th experiment: 37 updates!
# 253th experiment: 39 updates!
# 254th experiment: 39 updates!
# 255th experiment: 35 updates!
# 256th experiment: 31 updates!
# 257th experiment: 45 updates!
# 258th experiment: 77 updates!
# 259th experiment: 60 updates!
# 260th experiment: 39 updates!
# 261th experiment: 37 updates!
# 262th experiment: 35 updates!
# 263th experiment: 48 updates!
# 264th experiment: 37 updates!
# 265th experiment: 39 updates!
# 266th experiment: 52 updates!
# 267th experiment: 33 updates!
# 268th experiment: 11 updates!
# 269th experiment: 41 updates!
# 270th experiment: 39 updates!
# 271th experiment: 45 updates!
# 272th experiment: 24 updates!
# 273th experiment: 37 updates!
# 274th experiment: 37 updates!
# 275th experiment: 51 updates!
# 276th experiment: 39 updates!
# 277th experiment: 37 updates!
# 278th experiment: 56 updates!
# 279th experiment: 39 updates!
# 280th experiment: 39 updates!
# 281th experiment: 22 updates!
# 282th experiment: 39 updates!
# 283th experiment: 35 updates!
# 284th experiment: 56 updates!
# 285th experiment: 33 updates!
# 286th experiment: 56 updates!
# 287th experiment: 22 updates!
# 288th experiment: 33 updates!
# 289th experiment: 39 updates!
# 290th experiment: 41 updates!
# 291th experiment: 52 updates!
# 292th experiment: 45 updates!
# 293th experiment: 31 updates!
# 294th experiment: 35 updates!
# 295th experiment: 39 updates!
# 296th experiment: 35 updates!
# 297th experiment: 39 updates!
# 298th experiment: 43 updates!
# 299th experiment: 45 updates!
# 300th experiment: 33 updates!
# 301th experiment: 31 updates!
# 302th experiment: 54 updates!
# 303th experiment: 33 updates!
# 304th experiment: 54 updates!
# 305th experiment: 35 updates!
# 306th experiment: 54 updates!
# 307th experiment: 60 updates!
# 308th experiment: 37 updates!
# 309th experiment: 22 updates!
# 310th experiment: 39 updates!
# 311th experiment: 62 updates!
# 312th experiment: 37 updates!
# 313th experiment: 26 updates!
# 314th experiment: 47 updates!
# 315th experiment: 45 updates!
# 316th experiment: 39 updates!
# 317th experiment: 39 updates!
# 318th experiment: 20 updates!
# 319th experiment: 43 updates!
# 320th experiment: 33 updates!
# 321th experiment: 35 updates!
# 322th experiment: 54 updates!
# 323th experiment: 50 updates!
# 324th experiment: 35 updates!
# 325th experiment: 43 updates!
# 326th experiment: 35 updates!
# 327th experiment: 22 updates!
# 328th experiment: 22 updates!
# 329th experiment: 39 updates!
# 330th experiment: 43 updates!
# 331th experiment: 43 updates!
# 332th experiment: 39 updates!
# 333th experiment: 33 updates!
# 334th experiment: 60 updates!
# 335th experiment: 47 updates!
# 336th experiment: 35 updates!
# 337th experiment: 26 updates!
# 338th experiment: 20 updates!
# 339th experiment: 66 updates!
# 340th experiment: 16 updates!
# 341th experiment: 31 updates!
# 342th experiment: 43 updates!
# 343th experiment: 37 updates!
# 344th experiment: 45 updates!
# 345th experiment: 60 updates!
# 346th experiment: 54 updates!
# 347th experiment: 24 updates!
# 348th experiment: 35 updates!
# 349th experiment: 22 updates!
# 350th experiment: 43 updates!
# 351th experiment: 54 updates!
# 352th experiment: 41 updates!
# 353th experiment: 37 updates!
# 354th experiment: 35 updates!
# 355th experiment: 46 updates!
# 356th experiment: 54 updates!
# 357th experiment: 39 updates!
# 358th experiment: 20 updates!
# 359th experiment: 41 updates!
# 360th experiment: 43 updates!
# 361th experiment: 62 updates!
# 362th experiment: 60 updates!
# 363th experiment: 24 updates!
# 364th experiment: 24 updates!
# 365th experiment: 33 updates!
# 366th experiment: 73 updates!
# 367th experiment: 60 updates!
# 368th experiment: 37 updates!
# 369th experiment: 45 updates!
# 370th experiment: 26 updates!
# 371th experiment: 60 updates!
# 372th experiment: 41 updates!
# 373th experiment: 39 updates!
# 374th experiment: 33 updates!
# 375th experiment: 37 updates!
# 376th experiment: 50 updates!
# 377th experiment: 39 updates!
# 378th experiment: 31 updates!
# 379th experiment: 24 updates!
# 380th experiment: 43 updates!
# 381th experiment: 33 updates!
# 382th experiment: 43 updates!
# 383th experiment: 37 updates!
# 384th experiment: 35 updates!
# 385th experiment: 45 updates!
# 386th experiment: 41 updates!
# 387th experiment: 28 updates!
# 388th experiment: 37 updates!
# 389th experiment: 37 updates!
# 390th experiment: 43 updates!
# 391th experiment: 29 updates!
# 392th experiment: 35 updates!
# 393th experiment: 35 updates!
# 394th experiment: 39 updates!
# 395th experiment: 54 updates!
# 396th experiment: 41 updates!
# 397th experiment: 45 updates!
# 398th experiment: 29 updates!
# 399th experiment: 58 updates!
# 400th experiment: 24 updates!
# 401th experiment: 39 updates!
# 402th experiment: 24 updates!
# 403th experiment: 33 updates!
# 404th experiment: 24 updates!
# 405th experiment: 56 updates!
# 406th experiment: 39 updates!
# 407th experiment: 60 updates!
# 408th experiment: 47 updates!
# 409th experiment: 26 updates!
# 410th experiment: 54 updates!
# 411th experiment: 39 updates!
# 412th experiment: 39 updates!
# 413th experiment: 37 updates!
# 414th experiment: 62 updates!
# 415th experiment: 24 updates!
# 416th experiment: 39 updates!
# 417th experiment: 37 updates!
# 418th experiment: 35 updates!
# 419th experiment: 41 updates!
# 420th experiment: 41 updates!
# 421th experiment: 43 updates!
# 422th experiment: 28 updates!
# 423th experiment: 22 updates!
# 424th experiment: 41 updates!
# 425th experiment: 39 updates!
# 426th experiment: 50 updates!
# 427th experiment: 35 updates!
# 428th experiment: 39 updates!
# 429th experiment: 50 updates!
# 430th experiment: 24 updates!
# 431th experiment: 35 updates!
# 432th experiment: 39 updates!
# 433th experiment: 41 updates!
# 434th experiment: 52 updates!
# 435th experiment: 35 updates!
# 436th experiment: 58 updates!
# 437th experiment: 31 updates!
# 438th experiment: 39 updates!
# 439th experiment: 54 updates!
# 440th experiment: 22 updates!
# 441th experiment: 52 updates!
# 442th experiment: 43 updates!
# 443th experiment: 33 updates!
# 444th experiment: 35 updates!
# 445th experiment: 18 updates!
# 446th experiment: 35 updates!
# 447th experiment: 39 updates!
# 448th experiment: 64 updates!
# 449th experiment: 56 updates!
# 450th experiment: 26 updates!
# 451th experiment: 62 updates!
# 452th experiment: 37 updates!
# 453th experiment: 33 updates!
# 454th experiment: 68 updates!
# 455th experiment: 26 updates!
# 456th experiment: 58 updates!
# 457th experiment: 45 updates!
# 458th experiment: 50 updates!
# 459th experiment: 26 updates!
# 460th experiment: 43 updates!
# 461th experiment: 39 updates!
# 462th experiment: 41 updates!
# 463th experiment: 64 updates!
# 464th experiment: 41 updates!
# 465th experiment: 37 updates!
# 466th experiment: 45 updates!
# 467th experiment: 43 updates!
# 468th experiment: 37 updates!
# 469th experiment: 41 updates!
# 470th experiment: 47 updates!
# 471th experiment: 66 updates!
# 472th experiment: 37 updates!
# 473th experiment: 26 updates!
# 474th experiment: 41 updates!
# 475th experiment: 45 updates!
# 476th experiment: 41 updates!
# 477th experiment: 29 updates!
# 478th experiment: 41 updates!
# 479th experiment: 52 updates!
# 480th experiment: 39 updates!
# 481th experiment: 33 updates!
# 482th experiment: 62 updates!
# 483th experiment: 37 updates!
# 484th experiment: 39 updates!
# 485th experiment: 41 updates!
# 486th experiment: 35 updates!
# 487th experiment: 28 updates!
# 488th experiment: 39 updates!
# 489th experiment: 18 updates!
# 490th experiment: 35 updates!
# 491th experiment: 54 updates!
# 492th experiment: 41 updates!
# 493th experiment: 41 updates!
# 494th experiment: 58 updates!
# 495th experiment: 35 updates!
# 496th experiment: 39 updates!
# 497th experiment: 54 updates!
# 498th experiment: 41 updates!
# 499th experiment: 54 updates!
# 500th experiment: 37 updates!
# 501th experiment: 30 updates!
# 502th experiment: 43 updates!
# 503th experiment: 58 updates!
# 504th experiment: 39 updates!
# 505th experiment: 58 updates!
# 506th experiment: 49 updates!
# 507th experiment: 33 updates!
# 508th experiment: 31 updates!
# 509th experiment: 56 updates!
# 510th experiment: 22 updates!
# 511th experiment: 45 updates!
# 512th experiment: 39 updates!
# 513th experiment: 20 updates!
# 514th experiment: 37 updates!
# 515th experiment: 41 updates!
# 516th experiment: 33 updates!
# 517th experiment: 45 updates!
# 518th experiment: 37 updates!
# 519th experiment: 37 updates!
# 520th experiment: 41 updates!
# 521th experiment: 47 updates!
# 522th experiment: 39 updates!
# 523th experiment: 66 updates!
# 524th experiment: 31 updates!
# 525th experiment: 45 updates!
# 526th experiment: 39 updates!
# 527th experiment: 49 updates!
# 528th experiment: 24 updates!
# 529th experiment: 52 updates!
# 530th experiment: 41 updates!
# 531th experiment: 41 updates!
# 532th experiment: 41 updates!
# 533th experiment: 52 updates!
# 534th experiment: 54 updates!
# 535th experiment: 47 updates!
# 536th experiment: 26 updates!
# 537th experiment: 62 updates!
# 538th experiment: 39 updates!
# 539th experiment: 54 updates!
# 540th experiment: 41 updates!
# 541th experiment: 39 updates!
# 542th experiment: 41 updates!
# 543th experiment: 58 updates!
# 544th experiment: 54 updates!
# 545th experiment: 52 updates!
# 546th experiment: 35 updates!
# 547th experiment: 39 updates!
# 548th experiment: 45 updates!
# 549th experiment: 45 updates!
# 550th experiment: 58 updates!
# 551th experiment: 41 updates!
# 552th experiment: 33 updates!
# 553th experiment: 41 updates!
# 554th experiment: 50 updates!
# 555th experiment: 52 updates!
# 556th experiment: 35 updates!
# 557th experiment: 54 updates!
# 558th experiment: 39 updates!
# 559th experiment: 35 updates!
# 560th experiment: 24 updates!
# 561th experiment: 43 updates!
# 562th experiment: 41 updates!
# 563th experiment: 22 updates!
# 564th experiment: 41 updates!
# 565th experiment: 56 updates!
# 566th experiment: 41 updates!
# 567th experiment: 31 updates!
# 568th experiment: 18 updates!
# 569th experiment: 33 updates!
# 570th experiment: 28 updates!
# 571th experiment: 37 updates!
# 572th experiment: 45 updates!
# 573th experiment: 37 updates!
# 574th experiment: 33 updates!
# 575th experiment: 43 updates!
# 576th experiment: 60 updates!
# 577th experiment: 39 updates!
# 578th experiment: 37 updates!
# 579th experiment: 54 updates!
# 580th experiment: 39 updates!
# 581th experiment: 39 updates!
# 582th experiment: 47 updates!
# 583th experiment: 39 updates!
# 584th experiment: 45 updates!
# 585th experiment: 35 updates!
# 586th experiment: 56 updates!
# 587th experiment: 58 updates!
# 588th experiment: 50 updates!
# 589th experiment: 22 updates!
# 590th experiment: 37 updates!
# 591th experiment: 39 updates!
# 592th experiment: 41 updates!
# 593th experiment: 41 updates!
# 594th experiment: 39 updates!
# 595th experiment: 41 updates!
# 596th experiment: 43 updates!
# 597th experiment: 37 updates!
# 598th experiment: 41 updates!
# 599th experiment: 56 updates!
# 600th experiment: 39 updates!
# 601th experiment: 54 updates!
# 602th experiment: 56 updates!
# 603th experiment: 54 updates!
# 604th experiment: 41 updates!
# 605th experiment: 41 updates!
# 606th experiment: 33 updates!
# 607th experiment: 37 updates!
# 608th experiment: 29 updates!
# 609th experiment: 33 updates!
# 610th experiment: 35 updates!
# 611th experiment: 41 updates!
# 612th experiment: 39 updates!
# 613th experiment: 56 updates!
# 614th experiment: 43 updates!
# 615th experiment: 37 updates!
# 616th experiment: 35 updates!
# 617th experiment: 26 updates!
# 618th experiment: 35 updates!
# 619th experiment: 37 updates!
# 620th experiment: 56 updates!
# 621th experiment: 35 updates!
# 622th experiment: 28 updates!
# 623th experiment: 37 updates!
# 624th experiment: 22 updates!
# 625th experiment: 60 updates!
# 626th experiment: 39 updates!
# 627th experiment: 35 updates!
# 628th experiment: 39 updates!
# 629th experiment: 35 updates!
# 630th experiment: 58 updates!
# 631th experiment: 33 updates!
# 632th experiment: 33 updates!
# 633th experiment: 41 updates!
# 634th experiment: 24 updates!
# 635th experiment: 39 updates!
# 636th experiment: 41 updates!
# 637th experiment: 45 updates!
# 638th experiment: 37 updates!
# 639th experiment: 52 updates!
# 640th experiment: 39 updates!
# 641th experiment: 62 updates!
# 642th experiment: 58 updates!
# 643th experiment: 45 updates!
# 644th experiment: 37 updates!
# 645th experiment: 31 updates!
# 646th experiment: 39 updates!
# 647th experiment: 50 updates!
# 648th experiment: 37 updates!
# 649th experiment: 58 updates!
# 650th experiment: 37 updates!
# 651th experiment: 54 updates!
# 652th experiment: 24 updates!
# 653th experiment: 58 updates!
# 654th experiment: 39 updates!
# 655th experiment: 54 updates!
# 656th experiment: 31 updates!
# 657th experiment: 35 updates!
# 658th experiment: 22 updates!
# 659th experiment: 58 updates!
# 660th experiment: 35 updates!
# 661th experiment: 43 updates!
# 662th experiment: 35 updates!
# 663th experiment: 39 updates!
# 664th experiment: 58 updates!
# 665th experiment: 45 updates!
# 666th experiment: 24 updates!
# 667th experiment: 54 updates!
# 668th experiment: 43 updates!
# 669th experiment: 41 updates!
# 670th experiment: 54 updates!
# 671th experiment: 22 updates!
# 672th experiment: 35 updates!
# 673th experiment: 41 updates!
# 674th experiment: 41 updates!
# 675th experiment: 41 updates!
# 676th experiment: 39 updates!
# 677th experiment: 39 updates!
# 678th experiment: 33 updates!
# 679th experiment: 35 updates!
# 680th experiment: 39 updates!
# 681th experiment: 45 updates!
# 682th experiment: 22 updates!
# 683th experiment: 39 updates!
# 684th experiment: 56 updates!
# 685th experiment: 60 updates!
# 686th experiment: 54 updates!
# 687th experiment: 48 updates!
# 688th experiment: 39 updates!
# 689th experiment: 56 updates!
# 690th experiment: 31 updates!
# 691th experiment: 41 updates!
# 692th experiment: 54 updates!
# 693th experiment: 24 updates!
# 694th experiment: 62 updates!
# 695th experiment: 35 updates!
# 696th experiment: 35 updates!
# 697th experiment: 37 updates!
# 698th experiment: 26 updates!
# 699th experiment: 27 updates!
# 700th experiment: 70 updates!
# 701th experiment: 26 updates!
# 702th experiment: 39 updates!
# 703th experiment: 24 updates!
# 704th experiment: 33 updates!
# 705th experiment: 22 updates!
# 706th experiment: 39 updates!
# 707th experiment: 58 updates!
# 708th experiment: 41 updates!
# 709th experiment: 37 updates!
# 710th experiment: 41 updates!
# 711th experiment: 56 updates!
# 712th experiment: 26 updates!
# 713th experiment: 37 updates!
# 714th experiment: 37 updates!
# 715th experiment: 39 updates!
# 716th experiment: 39 updates!
# 717th experiment: 39 updates!
# 718th experiment: 39 updates!
# 719th experiment: 37 updates!
# 720th experiment: 35 updates!
# 721th experiment: 33 updates!
# 722th experiment: 47 updates!
# 723th experiment: 48 updates!
# 724th experiment: 22 updates!
# 725th experiment: 24 updates!
# 726th experiment: 54 updates!
# 727th experiment: 22 updates!
# 728th experiment: 39 updates!
# 729th experiment: 43 updates!
# 730th experiment: 37 updates!
# 731th experiment: 43 updates!
# 732th experiment: 22 updates!
# 733th experiment: 30 updates!
# 734th experiment: 35 updates!
# 735th experiment: 20 updates!
# 736th experiment: 35 updates!
# 737th experiment: 56 updates!
# 738th experiment: 43 updates!
# 739th experiment: 39 updates!
# 740th experiment: 26 updates!
# 741th experiment: 41 updates!
# 742th experiment: 48 updates!
# 743th experiment: 41 updates!
# 744th experiment: 28 updates!
# 745th experiment: 58 updates!
# 746th experiment: 28 updates!
# 747th experiment: 39 updates!
# 748th experiment: 41 updates!
# 749th experiment: 43 updates!
# 750th experiment: 39 updates!
# 751th experiment: 41 updates!
# 752th experiment: 39 updates!
# 753th experiment: 35 updates!
# 754th experiment: 24 updates!
# 755th experiment: 26 updates!
# 756th experiment: 54 updates!
# 757th experiment: 37 updates!
# 758th experiment: 58 updates!
# 759th experiment: 52 updates!
# 760th experiment: 20 updates!
# 761th experiment: 39 updates!
# 762th experiment: 39 updates!
# 763th experiment: 26 updates!
# 764th experiment: 39 updates!
# 765th experiment: 50 updates!
# 766th experiment: 58 updates!
# 767th experiment: 37 updates!
# 768th experiment: 37 updates!
# 769th experiment: 43 updates!
# 770th experiment: 37 updates!
# 771th experiment: 26 updates!
# 772th experiment: 48 updates!
# 773th experiment: 37 updates!
# 774th experiment: 37 updates!
# 775th experiment: 39 updates!
# 776th experiment: 39 updates!
# 777th experiment: 22 updates!
# 778th experiment: 41 updates!
# 779th experiment: 58 updates!
# 780th experiment: 58 updates!
# 781th experiment: 31 updates!
# 782th experiment: 35 updates!
# 783th experiment: 37 updates!
# 784th experiment: 24 updates!
# 785th experiment: 58 updates!
# 786th experiment: 41 updates!
# 787th experiment: 33 updates!
# 788th experiment: 26 updates!
# 789th experiment: 71 updates!
# 790th experiment: 26 updates!
# 791th experiment: 39 updates!
# 792th experiment: 31 updates!
# 793th experiment: 62 updates!
# 794th experiment: 33 updates!
# 795th experiment: 37 updates!
# 796th experiment: 35 updates!
# 797th experiment: 37 updates!
# 798th experiment: 24 updates!
# 799th experiment: 22 updates!
# 800th experiment: 41 updates!
# 801th experiment: 35 updates!
# 802th experiment: 24 updates!
# 803th experiment: 41 updates!
# 804th experiment: 31 updates!
# 805th experiment: 60 updates!
# 806th experiment: 39 updates!
# 807th experiment: 66 updates!
# 808th experiment: 20 updates!
# 809th experiment: 60 updates!
# 810th experiment: 39 updates!
# 811th experiment: 52 updates!
# 812th experiment: 49 updates!
# 813th experiment: 37 updates!
# 814th experiment: 43 updates!
# 815th experiment: 60 updates!
# 816th experiment: 54 updates!
# 817th experiment: 41 updates!
# 818th experiment: 39 updates!
# 819th experiment: 35 updates!
# 820th experiment: 31 updates!
# 821th experiment: 35 updates!
# 822th experiment: 39 updates!
# 823th experiment: 37 updates!
# 824th experiment: 20 updates!
# 825th experiment: 56 updates!
# 826th experiment: 31 updates!
# 827th experiment: 41 updates!
# 828th experiment: 39 updates!
# 829th experiment: 39 updates!
# 830th experiment: 54 updates!
# 831th experiment: 24 updates!
# 832th experiment: 20 updates!
# 833th experiment: 39 updates!
# 834th experiment: 54 updates!
# 835th experiment: 41 updates!
# 836th experiment: 33 updates!
# 837th experiment: 22 updates!
# 838th experiment: 39 updates!
# 839th experiment: 39 updates!
# 840th experiment: 33 updates!
# 841th experiment: 24 updates!
# 842th experiment: 43 updates!
# 843th experiment: 26 updates!
# 844th experiment: 39 updates!
# 845th experiment: 37 updates!
# 846th experiment: 39 updates!
# 847th experiment: 68 updates!
# 848th experiment: 52 updates!
# 849th experiment: 22 updates!
# 850th experiment: 37 updates!
# 851th experiment: 41 updates!
# 852th experiment: 37 updates!
# 853th experiment: 50 updates!
# 854th experiment: 52 updates!
# 855th experiment: 35 updates!
# 856th experiment: 24 updates!
# 857th experiment: 33 updates!
# 858th experiment: 45 updates!
# 859th experiment: 60 updates!
# 860th experiment: 35 updates!
# 861th experiment: 35 updates!
# 862th experiment: 39 updates!
# 863th experiment: 48 updates!
# 864th experiment: 22 updates!
# 865th experiment: 33 updates!
# 866th experiment: 24 updates!
# 867th experiment: 22 updates!
# 868th experiment: 48 updates!
# 869th experiment: 48 updates!
# 870th experiment: 26 updates!
# 871th experiment: 35 updates!
# 872th experiment: 37 updates!
# 873th experiment: 35 updates!
# 874th experiment: 39 updates!
# 875th experiment: 37 updates!
# 876th experiment: 37 updates!
# 877th experiment: 41 updates!
# 878th experiment: 41 updates!
# 879th experiment: 35 updates!
# 880th experiment: 24 updates!
# 881th experiment: 56 updates!
# 882th experiment: 33 updates!
# 883th experiment: 35 updates!
# 884th experiment: 31 updates!
# 885th experiment: 46 updates!
# 886th experiment: 37 updates!
# 887th experiment: 26 updates!
# 888th experiment: 35 updates!
# 889th experiment: 35 updates!
# 890th experiment: 39 updates!
# 891th experiment: 33 updates!
# 892th experiment: 58 updates!
# 893th experiment: 37 updates!
# 894th experiment: 37 updates!
# 895th experiment: 35 updates!
# 896th experiment: 24 updates!
# 897th experiment: 20 updates!
# 898th experiment: 26 updates!
# 899th experiment: 28 updates!
# 900th experiment: 52 updates!
# 901th experiment: 22 updates!
# 902th experiment: 33 updates!
# 903th experiment: 39 updates!
# 904th experiment: 29 updates!
# 905th experiment: 56 updates!
# 906th experiment: 41 updates!
# 907th experiment: 33 updates!
# 908th experiment: 33 updates!
# 909th experiment: 56 updates!
# 910th experiment: 35 updates!
# 911th experiment: 54 updates!
# 912th experiment: 43 updates!
# 913th experiment: 39 updates!
# 914th experiment: 39 updates!
# 915th experiment: 20 updates!
# 916th experiment: 60 updates!
# 917th experiment: 45 updates!
# 918th experiment: 35 updates!
# 919th experiment: 54 updates!
# 920th experiment: 43 updates!
# 921th experiment: 35 updates!
# 922th experiment: 33 updates!
# 923th experiment: 37 updates!
# 924th experiment: 37 updates!
# 925th experiment: 48 updates!
# 926th experiment: 54 updates!
# 927th experiment: 39 updates!
# 928th experiment: 58 updates!
# 929th experiment: 41 updates!
# 930th experiment: 43 updates!
# 931th experiment: 37 updates!
# 932th experiment: 50 updates!
# 933th experiment: 37 updates!
# 934th experiment: 73 updates!
# 935th experiment: 39 updates!
# 936th experiment: 33 updates!
# 937th experiment: 22 updates!
# 938th experiment: 41 updates!
# 939th experiment: 31 updates!
# 940th experiment: 35 updates!
# 941th experiment: 16 updates!
# 942th experiment: 24 updates!
# 943th experiment: 37 updates!
# 944th experiment: 45 updates!
# 945th experiment: 45 updates!
# 946th experiment: 41 updates!
# 947th experiment: 43 updates!
# 948th experiment: 26 updates!
# 949th experiment: 48 updates!
# 950th experiment: 39 updates!
# 951th experiment: 37 updates!
# 952th experiment: 43 updates!
# 953th experiment: 43 updates!
# 954th experiment: 35 updates!
# 955th experiment: 43 updates!
# 956th experiment: 37 updates!
# 957th experiment: 33 updates!
# 958th experiment: 39 updates!
# 959th experiment: 52 updates!
# 960th experiment: 50 updates!
# 961th experiment: 41 updates!
# 962th experiment: 26 updates!
# 963th experiment: 43 updates!
# 964th experiment: 20 updates!
# 965th experiment: 54 updates!
# 966th experiment: 39 updates!
# 967th experiment: 54 updates!
# 968th experiment: 33 updates!
# 969th experiment: 18 updates!
# 970th experiment: 39 updates!
# 971th experiment: 39 updates!
# 972th experiment: 35 updates!
# 973th experiment: 54 updates!
# 974th experiment: 50 updates!
# 975th experiment: 35 updates!
# 976th experiment: 35 updates!
# 977th experiment: 24 updates!
# 978th experiment: 58 updates!
# 979th experiment: 70 updates!
# 980th experiment: 29 updates!
# 981th experiment: 45 updates!
# 982th experiment: 31 updates!
# 983th experiment: 37 updates!
# 984th experiment: 22 updates!
# 985th experiment: 39 updates!
# 986th experiment: 41 updates!
# 987th experiment: 37 updates!
# 988th experiment: 24 updates!
# 989th experiment: 37 updates!
# 990th experiment: 37 updates!
# 991th experiment: 54 updates!
# 992th experiment: 56 updates!
# 993th experiment: 20 updates!
# 994th experiment: 35 updates!
# 995th experiment: 41 updates!
# 996th experiment: 24 updates!
# 997th experiment: 39 updates!
# 998th experiment: 56 updates!
# 999th experiment: 37 updates!
# 1000th experiment: 52 updates!
# 1001th experiment: 26 updates!
# 1002th experiment: 37 updates!
# 1003th experiment: 39 updates!
# 1004th experiment: 58 updates!
# 1005th experiment: 43 updates!
# 1006th experiment: 39 updates!
# 1007th experiment: 64 updates!
# 1008th experiment: 35 updates!
# 1009th experiment: 56 updates!
# 1010th experiment: 24 updates!
# 1011th experiment: 43 updates!
# 1012th experiment: 31 updates!
# 1013th experiment: 31 updates!
# 1014th experiment: 29 updates!
# 1015th experiment: 41 updates!
# 1016th experiment: 39 updates!
# 1017th experiment: 37 updates!
# 1018th experiment: 56 updates!
# 1019th experiment: 52 updates!
# 1020th experiment: 31 updates!
# 1021th experiment: 35 updates!
# 1022th experiment: 41 updates!
# 1023th experiment: 39 updates!
# 1024th experiment: 31 updates!
# 1025th experiment: 37 updates!
# 1026th experiment: 43 updates!
# 1027th experiment: 58 updates!
# 1028th experiment: 35 updates!
# 1029th experiment: 31 updates!
# 1030th experiment: 37 updates!
# 1031th experiment: 54 updates!
# 1032th experiment: 47 updates!
# 1033th experiment: 35 updates!
# 1034th experiment: 43 updates!
# 1035th experiment: 7 updates!
# 1036th experiment: 18 updates!
# 1037th experiment: 50 updates!
# 1038th experiment: 54 updates!
# 1039th experiment: 52 updates!
# 1040th experiment: 60 updates!
# 1041th experiment: 35 updates!
# 1042th experiment: 37 updates!
# 1043th experiment: 50 updates!
# 1044th experiment: 41 updates!
# 1045th experiment: 60 updates!
# 1046th experiment: 41 updates!
# 1047th experiment: 56 updates!
# 1048th experiment: 22 updates!
# 1049th experiment: 24 updates!
# 1050th experiment: 41 updates!
# 1051th experiment: 26 updates!
# 1052th experiment: 39 updates!
# 1053th experiment: 62 updates!
# 1054th experiment: 22 updates!
# 1055th experiment: 52 updates!
# 1056th experiment: 37 updates!
# 1057th experiment: 37 updates!
# 1058th experiment: 26 updates!
# 1059th experiment: 58 updates!
# 1060th experiment: 52 updates!
# 1061th experiment: 37 updates!
# 1062th experiment: 43 updates!
# 1063th experiment: 43 updates!
# 1064th experiment: 45 updates!
# 1065th experiment: 66 updates!
# 1066th experiment: 43 updates!
# 1067th experiment: 37 updates!
# 1068th experiment: 41 updates!
# 1069th experiment: 54 updates!
# 1070th experiment: 22 updates!
# 1071th experiment: 45 updates!
# 1072th experiment: 39 updates!
# 1073th experiment: 56 updates!
# 1074th experiment: 20 updates!
# 1075th experiment: 24 updates!
# 1076th experiment: 37 updates!
# 1077th experiment: 58 updates!
# 1078th experiment: 41 updates!
# 1079th experiment: 22 updates!
# 1080th experiment: 41 updates!
# 1081th experiment: 52 updates!
# 1082th experiment: 62 updates!
# 1083th experiment: 22 updates!
# 1084th experiment: 39 updates!
# 1085th experiment: 41 updates!
# 1086th experiment: 81 updates!
# 1087th experiment: 26 updates!
# 1088th experiment: 20 updates!
# 1089th experiment: 22 updates!
# 1090th experiment: 35 updates!
# 1091th experiment: 37 updates!
# 1092th experiment: 9 updates!
# 1093th experiment: 22 updates!
# 1094th experiment: 75 updates!
# 1095th experiment: 60 updates!
# 1096th experiment: 22 updates!
# 1097th experiment: 39 updates!
# 1098th experiment: 37 updates!
# 1099th experiment: 41 updates!
# 1100th experiment: 56 updates!
# 1101th experiment: 39 updates!
# 1102th experiment: 37 updates!
# 1103th experiment: 66 updates!
# 1104th experiment: 37 updates!
# 1105th experiment: 35 updates!
# 1106th experiment: 33 updates!
# 1107th experiment: 60 updates!
# 1108th experiment: 35 updates!
# 1109th experiment: 41 updates!
# 1110th experiment: 56 updates!
# 1111th experiment: 35 updates!
# 1112th experiment: 37 updates!
# 1113th experiment: 37 updates!
# 1114th experiment: 37 updates!
# 1115th experiment: 39 updates!
# 1116th experiment: 41 updates!
# 1117th experiment: 43 updates!
# 1118th experiment: 45 updates!
# 1119th experiment: 37 updates!
# 1120th experiment: 35 updates!
# 1121th experiment: 43 updates!
# 1122th experiment: 60 updates!
# 1123th experiment: 33 updates!
# 1124th experiment: 35 updates!
# 1125th experiment: 39 updates!
# 1126th experiment: 26 updates!
# 1127th experiment: 26 updates!
# 1128th experiment: 75 updates!
# 1129th experiment: 45 updates!
# 1130th experiment: 39 updates!
# 1131th experiment: 37 updates!
# 1132th experiment: 33 updates!
# 1133th experiment: 37 updates!
# 1134th experiment: 41 updates!
# 1135th experiment: 39 updates!
# 1136th experiment: 47 updates!
# 1137th experiment: 33 updates!
# 1138th experiment: 54 updates!
# 1139th experiment: 62 updates!
# 1140th experiment: 39 updates!
# 1141th experiment: 39 updates!
# 1142th experiment: 41 updates!
# 1143th experiment: 37 updates!
# 1144th experiment: 45 updates!
# 1145th experiment: 41 updates!
# 1146th experiment: 33 updates!
# 1147th experiment: 33 updates!
# 1148th experiment: 24 updates!
# 1149th experiment: 35 updates!
# 1150th experiment: 35 updates!
# 1151th experiment: 41 updates!
# 1152th experiment: 24 updates!
# 1153th experiment: 33 updates!
# 1154th experiment: 22 updates!
# 1155th experiment: 56 updates!
# 1156th experiment: 60 updates!
# 1157th experiment: 11 updates!
# 1158th experiment: 39 updates!
# 1159th experiment: 39 updates!
# 1160th experiment: 35 updates!
# 1161th experiment: 20 updates!
# 1162th experiment: 56 updates!
# 1163th experiment: 58 updates!
# 1164th experiment: 37 updates!
# 1165th experiment: 45 updates!
# 1166th experiment: 48 updates!
# 1167th experiment: 56 updates!
# 1168th experiment: 56 updates!
# 1169th experiment: 54 updates!
# 1170th experiment: 22 updates!
# 1171th experiment: 41 updates!
# 1172th experiment: 26 updates!
# 1173th experiment: 33 updates!
# 1174th experiment: 35 updates!
# 1175th experiment: 41 updates!
# 1176th experiment: 31 updates!
# 1177th experiment: 52 updates!
# 1178th experiment: 37 updates!
# 1179th experiment: 33 updates!
# 1180th experiment: 52 updates!
# 1181th experiment: 45 updates!
# 1182th experiment: 35 updates!
# 1183th experiment: 18 updates!
# 1184th experiment: 54 updates!
# 1185th experiment: 54 updates!
# 1186th experiment: 33 updates!
# 1187th experiment: 9 updates!
# 1188th experiment: 41 updates!
# 1189th experiment: 60 updates!
# 1190th experiment: 62 updates!
# 1191th experiment: 39 updates!
# 1192th experiment: 26 updates!
# 1193th experiment: 39 updates!
# 1194th experiment: 77 updates!
# 1195th experiment: 35 updates!
# 1196th experiment: 39 updates!
# 1197th experiment: 45 updates!
# 1198th experiment: 39 updates!
# 1199th experiment: 56 updates!
# 1200th experiment: 56 updates!
# 1201th experiment: 39 updates!
# 1202th experiment: 52 updates!
# 1203th experiment: 41 updates!
# 1204th experiment: 37 updates!
# 1205th experiment: 41 updates!
# 1206th experiment: 24 updates!
# 1207th experiment: 66 updates!
# 1208th experiment: 20 updates!
# 1209th experiment: 28 updates!
# 1210th experiment: 35 updates!
# 1211th experiment: 43 updates!
# 1212th experiment: 37 updates!
# 1213th experiment: 33 updates!
# 1214th experiment: 41 updates!
# 1215th experiment: 41 updates!
# 1216th experiment: 31 updates!
# 1217th experiment: 39 updates!
# 1218th experiment: 22 updates!
# 1219th experiment: 35 updates!
# 1220th experiment: 39 updates!
# 1221th experiment: 24 updates!
# 1222th experiment: 37 updates!
# 1223th experiment: 39 updates!
# 1224th experiment: 35 updates!
# 1225th experiment: 35 updates!
# 1226th experiment: 24 updates!
# 1227th experiment: 41 updates!
# 1228th experiment: 37 updates!
# 1229th experiment: 56 updates!
# 1230th experiment: 41 updates!
# 1231th experiment: 39 updates!
# 1232th experiment: 39 updates!
# 1233th experiment: 22 updates!
# 1234th experiment: 37 updates!
# 1235th experiment: 35 updates!
# 1236th experiment: 22 updates!
# 1237th experiment: 24 updates!
# 1238th experiment: 43 updates!
# 1239th experiment: 56 updates!
# 1240th experiment: 35 updates!
# 1241th experiment: 35 updates!
# 1242th experiment: 41 updates!
# 1243th experiment: 54 updates!
# 1244th experiment: 18 updates!
# 1245th experiment: 26 updates!
# 1246th experiment: 26 updates!
# 1247th experiment: 37 updates!
# 1248th experiment: 50 updates!
# 1249th experiment: 24 updates!
# 1250th experiment: 37 updates!
# 1251th experiment: 24 updates!
# 1252th experiment: 33 updates!
# 1253th experiment: 39 updates!
# 1254th experiment: 20 updates!
# 1255th experiment: 58 updates!
# 1256th experiment: 39 updates!
# 1257th experiment: 41 updates!
# 1258th experiment: 30 updates!
# 1259th experiment: 37 updates!
# 1260th experiment: 37 updates!
# 1261th experiment: 35 updates!
# 1262th experiment: 28 updates!
# 1263th experiment: 54 updates!
# 1264th experiment: 39 updates!
# 1265th experiment: 43 updates!
# 1266th experiment: 62 updates!
# 1267th experiment: 58 updates!
# 1268th experiment: 43 updates!
# 1269th experiment: 37 updates!
# 1270th experiment: 54 updates!
# 1271th experiment: 56 updates!
# 1272th experiment: 37 updates!
# 1273th experiment: 39 updates!
# 1274th experiment: 31 updates!
# 1275th experiment: 22 updates!
# 1276th experiment: 24 updates!
# 1277th experiment: 41 updates!
# 1278th experiment: 35 updates!
# 1279th experiment: 20 updates!
# 1280th experiment: 43 updates!
# 1281th experiment: 26 updates!
# 1282th experiment: 54 updates!
# 1283th experiment: 56 updates!
# 1284th experiment: 54 updates!
# 1285th experiment: 26 updates!
# 1286th experiment: 45 updates!
# 1287th experiment: 43 updates!
# 1288th experiment: 52 updates!
# 1289th experiment: 7 updates!
# 1290th experiment: 41 updates!
# 1291th experiment: 41 updates!
# 1292th experiment: 39 updates!
# 1293th experiment: 22 updates!
# 1294th experiment: 20 updates!
# 1295th experiment: 35 updates!
# 1296th experiment: 35 updates!
# 1297th experiment: 18 updates!
# 1298th experiment: 39 updates!
# 1299th experiment: 29 updates!
# 1300th experiment: 58 updates!
# 1301th experiment: 24 updates!
# 1302th experiment: 37 updates!
# 1303th experiment: 35 updates!
# 1304th experiment: 43 updates!
# 1305th experiment: 37 updates!
# 1306th experiment: 50 updates!
# 1307th experiment: 33 updates!
# 1308th experiment: 33 updates!
# 1309th experiment: 37 updates!
# 1310th experiment: 37 updates!
# 1311th experiment: 24 updates!
# 1312th experiment: 39 updates!
# 1313th experiment: 35 updates!
# 1314th experiment: 50 updates!
# 1315th experiment: 62 updates!
# 1316th experiment: 41 updates!
# 1317th experiment: 24 updates!
# 1318th experiment: 41 updates!
# 1319th experiment: 9 updates!
# 1320th experiment: 56 updates!
# 1321th experiment: 50 updates!
# 1322th experiment: 41 updates!
# 1323th experiment: 62 updates!
# 1324th experiment: 22 updates!
# 1325th experiment: 22 updates!
# 1326th experiment: 37 updates!
# 1327th experiment: 39 updates!
# 1328th experiment: 35 updates!
# 1329th experiment: 43 updates!
# 1330th experiment: 35 updates!
# 1331th experiment: 37 updates!
# 1332th experiment: 37 updates!
# 1333th experiment: 37 updates!
# 1334th experiment: 24 updates!
# 1335th experiment: 41 updates!
# 1336th experiment: 20 updates!
# 1337th experiment: 45 updates!
# 1338th experiment: 60 updates!
# 1339th experiment: 24 updates!
# 1340th experiment: 60 updates!
# 1341th experiment: 18 updates!
# 1342th experiment: 41 updates!
# 1343th experiment: 56 updates!
# 1344th experiment: 58 updates!
# 1345th experiment: 37 updates!
# 1346th experiment: 60 updates!
# 1347th experiment: 41 updates!
# 1348th experiment: 24 updates!
# 1349th experiment: 52 updates!
# 1350th experiment: 35 updates!
# 1351th experiment: 37 updates!
# 1352th experiment: 33 updates!
# 1353th experiment: 20 updates!
# 1354th experiment: 37 updates!
# 1355th experiment: 33 updates!
# 1356th experiment: 52 updates!
# 1357th experiment: 39 updates!
# 1358th experiment: 37 updates!
# 1359th experiment: 39 updates!
# 1360th experiment: 24 updates!
# 1361th experiment: 35 updates!
# 1362th experiment: 37 updates!
# 1363th experiment: 56 updates!
# 1364th experiment: 41 updates!
# 1365th experiment: 43 updates!
# 1366th experiment: 45 updates!
# 1367th experiment: 35 updates!
# 1368th experiment: 24 updates!
# 1369th experiment: 16 updates!
# 1370th experiment: 44 updates!
# 1371th experiment: 39 updates!
# 1372th experiment: 20 updates!
# 1373th experiment: 54 updates!
# 1374th experiment: 37 updates!
# 1375th experiment: 20 updates!
# 1376th experiment: 41 updates!
# 1377th experiment: 43 updates!
# 1378th experiment: 29 updates!
# 1379th experiment: 62 updates!
# 1380th experiment: 56 updates!
# 1381th experiment: 35 updates!
# 1382th experiment: 26 updates!
# 1383th experiment: 41 updates!
# 1384th experiment: 45 updates!
# 1385th experiment: 39 updates!
# 1386th experiment: 39 updates!
# 1387th experiment: 33 updates!
# 1388th experiment: 18 updates!
# 1389th experiment: 39 updates!
# 1390th experiment: 45 updates!
# 1391th experiment: 33 updates!
# 1392th experiment: 35 updates!
# 1393th experiment: 24 updates!
# 1394th experiment: 37 updates!
# 1395th experiment: 26 updates!
# 1396th experiment: 56 updates!
# 1397th experiment: 26 updates!
# 1398th experiment: 46 updates!
# 1399th experiment: 41 updates!
# 1400th experiment: 54 updates!
# 1401th experiment: 47 updates!
# 1402th experiment: 35 updates!
# 1403th experiment: 22 updates!
# 1404th experiment: 35 updates!
# 1405th experiment: 41 updates!
# 1406th experiment: 56 updates!
# 1407th experiment: 39 updates!
# 1408th experiment: 18 updates!
# 1409th experiment: 41 updates!
# 1410th experiment: 39 updates!
# 1411th experiment: 43 updates!
# 1412th experiment: 20 updates!
# 1413th experiment: 41 updates!
# 1414th experiment: 52 updates!
# 1415th experiment: 43 updates!
# 1416th experiment: 35 updates!
# 1417th experiment: 54 updates!
# 1418th experiment: 60 updates!
# 1419th experiment: 43 updates!
# 1420th experiment: 31 updates!
# 1421th experiment: 43 updates!
# 1422th experiment: 52 updates!
# 1423th experiment: 43 updates!
# 1424th experiment: 43 updates!
# 1425th experiment: 41 updates!
# 1426th experiment: 41 updates!
# 1427th experiment: 41 updates!
# 1428th experiment: 18 updates!
# 1429th experiment: 41 updates!
# 1430th experiment: 56 updates!
# 1431th experiment: 58 updates!
# 1432th experiment: 50 updates!
# 1433th experiment: 31 updates!
# 1434th experiment: 54 updates!
# 1435th experiment: 56 updates!
# 1436th experiment: 41 updates!
# 1437th experiment: 35 updates!
# 1438th experiment: 31 updates!
# 1439th experiment: 58 updates!
# 1440th experiment: 52 updates!
# 1441th experiment: 24 updates!
# 1442th experiment: 56 updates!
# 1443th experiment: 37 updates!
# 1444th experiment: 41 updates!
# 1445th experiment: 37 updates!
# 1446th experiment: 50 updates!
# 1447th experiment: 39 updates!
# 1448th experiment: 16 updates!
# 1449th experiment: 35 updates!
# 1450th experiment: 43 updates!
# 1451th experiment: 26 updates!
# 1452th experiment: 77 updates!
# 1453th experiment: 39 updates!
# 1454th experiment: 35 updates!
# 1455th experiment: 62 updates!
# 1456th experiment: 24 updates!
# 1457th experiment: 33 updates!
# 1458th experiment: 33 updates!
# 1459th experiment: 37 updates!
# 1460th experiment: 56 updates!
# 1461th experiment: 52 updates!
# 1462th experiment: 37 updates!
# 1463th experiment: 52 updates!
# 1464th experiment: 41 updates!
# 1465th experiment: 37 updates!
# 1466th experiment: 33 updates!
# 1467th experiment: 22 updates!
# 1468th experiment: 43 updates!
# 1469th experiment: 39 updates!
# 1470th experiment: 28 updates!
# 1471th experiment: 47 updates!
# 1472th experiment: 49 updates!
# 1473th experiment: 24 updates!
# 1474th experiment: 28 updates!
# 1475th experiment: 41 updates!
# 1476th experiment: 41 updates!
# 1477th experiment: 52 updates!
# 1478th experiment: 41 updates!
# 1479th experiment: 58 updates!
# 1480th experiment: 43 updates!
# 1481th experiment: 35 updates!
# 1482th experiment: 50 updates!
# 1483th experiment: 24 updates!
# 1484th experiment: 43 updates!
# 1485th experiment: 58 updates!
# 1486th experiment: 31 updates!
# 1487th experiment: 20 updates!
# 1488th experiment: 39 updates!
# 1489th experiment: 39 updates!
# 1490th experiment: 58 updates!
# 1491th experiment: 45 updates!
# 1492th experiment: 39 updates!
# 1493th experiment: 18 updates!
# 1494th experiment: 43 updates!
# 1495th experiment: 56 updates!
# 1496th experiment: 37 updates!
# 1497th experiment: 39 updates!
# 1498th experiment: 35 updates!
# 1499th experiment: 39 updates!
# 1500th experiment: 37 updates!
# 1501th experiment: 9 updates!
# 1502th experiment: 28 updates!
# 1503th experiment: 35 updates!
# 1504th experiment: 41 updates!
# 1505th experiment: 35 updates!
# 1506th experiment: 54 updates!
# 1507th experiment: 73 updates!
# 1508th experiment: 37 updates!
# 1509th experiment: 39 updates!
# 1510th experiment: 39 updates!
# 1511th experiment: 62 updates!
# 1512th experiment: 35 updates!
# 1513th experiment: 37 updates!
# 1514th experiment: 18 updates!
# 1515th experiment: 58 updates!
# 1516th experiment: 39 updates!
# 1517th experiment: 37 updates!
# 1518th experiment: 39 updates!
# 1519th experiment: 56 updates!
# 1520th experiment: 58 updates!
# 1521th experiment: 37 updates!
# 1522th experiment: 45 updates!
# 1523th experiment: 56 updates!
# 1524th experiment: 37 updates!
# 1525th experiment: 26 updates!
# 1526th experiment: 54 updates!
# 1527th experiment: 47 updates!
# 1528th experiment: 41 updates!
# 1529th experiment: 20 updates!
# 1530th experiment: 35 updates!
# 1531th experiment: 41 updates!
# 1532th experiment: 62 updates!
# 1533th experiment: 48 updates!
# 1534th experiment: 58 updates!
# 1535th experiment: 24 updates!
# 1536th experiment: 37 updates!
# 1537th experiment: 39 updates!
# 1538th experiment: 22 updates!
# 1539th experiment: 11 updates!
# 1540th experiment: 35 updates!
# 1541th experiment: 20 updates!
# 1542th experiment: 43 updates!
# 1543th experiment: 35 updates!
# 1544th experiment: 22 updates!
# 1545th experiment: 33 updates!
# 1546th experiment: 43 updates!
# 1547th experiment: 60 updates!
# 1548th experiment: 62 updates!
# 1549th experiment: 35 updates!
# 1550th experiment: 41 updates!
# 1551th experiment: 39 updates!
# 1552th experiment: 52 updates!
# 1553th experiment: 37 updates!
# 1554th experiment: 37 updates!
# 1555th experiment: 37 updates!
# 1556th experiment: 39 updates!
# 1557th experiment: 41 updates!
# 1558th experiment: 52 updates!
# 1559th experiment: 41 updates!
# 1560th experiment: 35 updates!
# 1561th experiment: 29 updates!
# 1562th experiment: 58 updates!
# 1563th experiment: 35 updates!
# 1564th experiment: 33 updates!
# 1565th experiment: 54 updates!
# 1566th experiment: 35 updates!
# 1567th experiment: 39 updates!
# 1568th experiment: 41 updates!
# 1569th experiment: 26 updates!
# 1570th experiment: 54 updates!
# 1571th experiment: 60 updates!
# 1572th experiment: 56 updates!
# 1573th experiment: 56 updates!
# 1574th experiment: 54 updates!
# 1575th experiment: 20 updates!
# 1576th experiment: 39 updates!
# 1577th experiment: 35 updates!
# 1578th experiment: 41 updates!
# 1579th experiment: 37 updates!
# 1580th experiment: 31 updates!
# 1581th experiment: 33 updates!
# 1582th experiment: 39 updates!
# 1583th experiment: 22 updates!
# 1584th experiment: 30 updates!
# 1585th experiment: 20 updates!
# 1586th experiment: 20 updates!
# 1587th experiment: 33 updates!
# 1588th experiment: 24 updates!
# 1589th experiment: 45 updates!
# 1590th experiment: 35 updates!
# 1591th experiment: 64 updates!
# 1592th experiment: 47 updates!
# 1593th experiment: 20 updates!
# 1594th experiment: 54 updates!
# 1595th experiment: 22 updates!
# 1596th experiment: 39 updates!
# 1597th experiment: 37 updates!
# 1598th experiment: 24 updates!
# 1599th experiment: 30 updates!
# 1600th experiment: 37 updates!
# 1601th experiment: 26 updates!
# 1602th experiment: 62 updates!
# 1603th experiment: 43 updates!
# 1604th experiment: 56 updates!
# 1605th experiment: 69 updates!
# 1606th experiment: 58 updates!
# 1607th experiment: 26 updates!
# 1608th experiment: 54 updates!
# 1609th experiment: 26 updates!
# 1610th experiment: 35 updates!
# 1611th experiment: 52 updates!
# 1612th experiment: 41 updates!
# 1613th experiment: 58 updates!
# 1614th experiment: 39 updates!
# 1615th experiment: 33 updates!
# 1616th experiment: 9 updates!
# 1617th experiment: 41 updates!
# 1618th experiment: 24 updates!
# 1619th experiment: 37 updates!
# 1620th experiment: 26 updates!
# 1621th experiment: 39 updates!
# 1622th experiment: 35 updates!
# 1623th experiment: 45 updates!
# 1624th experiment: 35 updates!
# 1625th experiment: 20 updates!
# 1626th experiment: 52 updates!
# 1627th experiment: 20 updates!
# 1628th experiment: 33 updates!
# 1629th experiment: 56 updates!
# 1630th experiment: 24 updates!
# 1631th experiment: 52 updates!
# 1632th experiment: 48 updates!
# 1633th experiment: 9 updates!
# 1634th experiment: 43 updates!
# 1635th experiment: 64 updates!
# 1636th experiment: 43 updates!
# 1637th experiment: 24 updates!
# 1638th experiment: 60 updates!
# 1639th experiment: 41 updates!
# 1640th experiment: 20 updates!
# 1641th experiment: 41 updates!
# 1642th experiment: 62 updates!
# 1643th experiment: 39 updates!
# 1644th experiment: 24 updates!
# 1645th experiment: 50 updates!
# 1646th experiment: 60 updates!
# 1647th experiment: 45 updates!
# 1648th experiment: 64 updates!
# 1649th experiment: 45 updates!
# 1650th experiment: 30 updates!
# 1651th experiment: 45 updates!
# 1652th experiment: 54 updates!
# 1653th experiment: 41 updates!
# 1654th experiment: 35 updates!
# 1655th experiment: 26 updates!
# 1656th experiment: 41 updates!
# 1657th experiment: 41 updates!
# 1658th experiment: 50 updates!
# 1659th experiment: 52 updates!
# 1660th experiment: 75 updates!
# 1661th experiment: 41 updates!
# 1662th experiment: 28 updates!
# 1663th experiment: 29 updates!
# 1664th experiment: 41 updates!
# 1665th experiment: 56 updates!
# 1666th experiment: 31 updates!
# 1667th experiment: 39 updates!
# 1668th experiment: 28 updates!
# 1669th experiment: 24 updates!
# 1670th experiment: 50 updates!
# 1671th experiment: 62 updates!
# 1672th experiment: 39 updates!
# 1673th experiment: 60 updates!
# 1674th experiment: 39 updates!
# 1675th experiment: 45 updates!
# 1676th experiment: 35 updates!
# 1677th experiment: 43 updates!
# 1678th experiment: 37 updates!
# 1679th experiment: 33 updates!
# 1680th experiment: 24 updates!
# 1681th experiment: 37 updates!
# 1682th experiment: 58 updates!
# 1683th experiment: 39 updates!
# 1684th experiment: 73 updates!
# 1685th experiment: 20 updates!
# 1686th experiment: 35 updates!
# 1687th experiment: 47 updates!
# 1688th experiment: 41 updates!
# 1689th experiment: 24 updates!
# 1690th experiment: 41 updates!
# 1691th experiment: 39 updates!
# 1692th experiment: 33 updates!
# 1693th experiment: 33 updates!
# 1694th experiment: 37 updates!
# 1695th experiment: 50 updates!
# 1696th experiment: 37 updates!
# 1697th experiment: 39 updates!
# 1698th experiment: 20 updates!
# 1699th experiment: 64 updates!
# 1700th experiment: 31 updates!
# 1701th experiment: 60 updates!
# 1702th experiment: 45 updates!
# 1703th experiment: 20 updates!
# 1704th experiment: 54 updates!
# 1705th experiment: 60 updates!
# 1706th experiment: 54 updates!
# 1707th experiment: 37 updates!
# 1708th experiment: 43 updates!
# 1709th experiment: 22 updates!
# 1710th experiment: 33 updates!
# 1711th experiment: 31 updates!
# 1712th experiment: 37 updates!
# 1713th experiment: 52 updates!
# 1714th experiment: 54 updates!
# 1715th experiment: 49 updates!
# 1716th experiment: 37 updates!
# 1717th experiment: 39 updates!
# 1718th experiment: 22 updates!
# 1719th experiment: 47 updates!
# 1720th experiment: 54 updates!
# 1721th experiment: 60 updates!
# 1722th experiment: 33 updates!
# 1723th experiment: 33 updates!
# 1724th experiment: 26 updates!
# 1725th experiment: 39 updates!
# 1726th experiment: 43 updates!
# 1727th experiment: 45 updates!
# 1728th experiment: 52 updates!
# 1729th experiment: 35 updates!
# 1730th experiment: 43 updates!
# 1731th experiment: 37 updates!
# 1732th experiment: 37 updates!
# 1733th experiment: 39 updates!
# 1734th experiment: 35 updates!
# 1735th experiment: 39 updates!
# 1736th experiment: 54 updates!
# 1737th experiment: 37 updates!
# 1738th experiment: 64 updates!
# 1739th experiment: 56 updates!
# 1740th experiment: 41 updates!
# 1741th experiment: 28 updates!
# 1742th experiment: 35 updates!
# 1743th experiment: 37 updates!
# 1744th experiment: 37 updates!
# 1745th experiment: 54 updates!
# 1746th experiment: 43 updates!
# 1747th experiment: 22 updates!
# 1748th experiment: 26 updates!
# 1749th experiment: 37 updates!
# 1750th experiment: 45 updates!
# 1751th experiment: 58 updates!
# 1752th experiment: 37 updates!
# 1753th experiment: 41 updates!
# 1754th experiment: 39 updates!
# 1755th experiment: 54 updates!
# 1756th experiment: 45 updates!
# 1757th experiment: 54 updates!
# 1758th experiment: 39 updates!
# 1759th experiment: 37 updates!
# 1760th experiment: 31 updates!
# 1761th experiment: 24 updates!
# 1762th experiment: 41 updates!
# 1763th experiment: 45 updates!
# 1764th experiment: 37 updates!
# 1765th experiment: 41 updates!
# 1766th experiment: 28 updates!
# 1767th experiment: 41 updates!
# 1768th experiment: 37 updates!
# 1769th experiment: 45 updates!
# 1770th experiment: 62 updates!
# 1771th experiment: 62 updates!
# 1772th experiment: 62 updates!
# 1773th experiment: 35 updates!
# 1774th experiment: 20 updates!
# 1775th experiment: 54 updates!
# 1776th experiment: 54 updates!
# 1777th experiment: 37 updates!
# 1778th experiment: 7 updates!
# 1779th experiment: 35 updates!
# 1780th experiment: 50 updates!
# 1781th experiment: 28 updates!
# 1782th experiment: 43 updates!
# 1783th experiment: 41 updates!
# 1784th experiment: 35 updates!
# 1785th experiment: 39 updates!
# 1786th experiment: 60 updates!
# 1787th experiment: 22 updates!
# 1788th experiment: 22 updates!
# 1789th experiment: 37 updates!
# 1790th experiment: 31 updates!
# 1791th experiment: 39 updates!
# 1792th experiment: 37 updates!
# 1793th experiment: 52 updates!
# 1794th experiment: 39 updates!
# 1795th experiment: 39 updates!
# 1796th experiment: 43 updates!
# 1797th experiment: 39 updates!
# 1798th experiment: 41 updates!
# 1799th experiment: 37 updates!
# 1800th experiment: 56 updates!
# 1801th experiment: 39 updates!
# 1802th experiment: 24 updates!
# 1803th experiment: 35 updates!
# 1804th experiment: 43 updates!
# 1805th experiment: 33 updates!
# 1806th experiment: 20 updates!
# 1807th experiment: 22 updates!
# 1808th experiment: 54 updates!
# 1809th experiment: 33 updates!
# 1810th experiment: 39 updates!
# 1811th experiment: 20 updates!
# 1812th experiment: 31 updates!
# 1813th experiment: 41 updates!
# 1814th experiment: 43 updates!
# 1815th experiment: 41 updates!
# 1816th experiment: 24 updates!
# 1817th experiment: 52 updates!
# 1818th experiment: 41 updates!
# 1819th experiment: 22 updates!
# 1820th experiment: 45 updates!
# 1821th experiment: 33 updates!
# 1822th experiment: 43 updates!
# 1823th experiment: 22 updates!
# 1824th experiment: 37 updates!
# 1825th experiment: 26 updates!
# 1826th experiment: 39 updates!
# 1827th experiment: 43 updates!
# 1828th experiment: 39 updates!
# 1829th experiment: 22 updates!
# 1830th experiment: 31 updates!
# 1831th experiment: 33 updates!
# 1832th experiment: 22 updates!
# 1833th experiment: 26 updates!
# 1834th experiment: 24 updates!
# 1835th experiment: 47 updates!
# 1836th experiment: 43 updates!
# 1837th experiment: 20 updates!
# 1838th experiment: 22 updates!
# 1839th experiment: 58 updates!
# 1840th experiment: 54 updates!
# 1841th experiment: 56 updates!
# 1842th experiment: 41 updates!
# 1843th experiment: 26 updates!
# 1844th experiment: 39 updates!
# 1845th experiment: 39 updates!
# 1846th experiment: 39 updates!
# 1847th experiment: 47 updates!
# 1848th experiment: 24 updates!
# 1849th experiment: 60 updates!
# 1850th experiment: 56 updates!
# 1851th experiment: 39 updates!
# 1852th experiment: 43 updates!
# 1853th experiment: 56 updates!
# 1854th experiment: 52 updates!
# 1855th experiment: 60 updates!
# 1856th experiment: 46 updates!
# 1857th experiment: 37 updates!
# 1858th experiment: 35 updates!
# 1859th experiment: 41 updates!
# 1860th experiment: 60 updates!
# 1861th experiment: 35 updates!
# 1862th experiment: 39 updates!
# 1863th experiment: 45 updates!
# 1864th experiment: 28 updates!
# 1865th experiment: 48 updates!
# 1866th experiment: 39 updates!
# 1867th experiment: 37 updates!
# 1868th experiment: 39 updates!
# 1869th experiment: 37 updates!
# 1870th experiment: 33 updates!
# 1871th experiment: 37 updates!
# 1872th experiment: 13 updates!
# 1873th experiment: 56 updates!
# 1874th experiment: 56 updates!
# 1875th experiment: 24 updates!
# 1876th experiment: 24 updates!
# 1877th experiment: 46 updates!
# 1878th experiment: 35 updates!
# 1879th experiment: 41 updates!
# 1880th experiment: 39 updates!
# 1881th experiment: 31 updates!
# 1882th experiment: 37 updates!
# 1883th experiment: 39 updates!
# 1884th experiment: 62 updates!
# 1885th experiment: 56 updates!
# 1886th experiment: 52 updates!
# 1887th experiment: 26 updates!
# 1888th experiment: 45 updates!
# 1889th experiment: 39 updates!
# 1890th experiment: 37 updates!
# 1891th experiment: 37 updates!
# 1892th experiment: 43 updates!
# 1893th experiment: 48 updates!
# 1894th experiment: 24 updates!
# 1895th experiment: 11 updates!
# 1896th experiment: 43 updates!
# 1897th experiment: 54 updates!
# 1898th experiment: 37 updates!
# 1899th experiment: 26 updates!
# 1900th experiment: 54 updates!
# 1901th experiment: 22 updates!
# 1902th experiment: 35 updates!
# 1903th experiment: 45 updates!
# 1904th experiment: 41 updates!
# 1905th experiment: 62 updates!
# 1906th experiment: 35 updates!
# 1907th experiment: 58 updates!
# 1908th experiment: 43 updates!
# 1909th experiment: 31 updates!
# 1910th experiment: 22 updates!
# 1911th experiment: 37 updates!
# 1912th experiment: 56 updates!
# 1913th experiment: 31 updates!
# 1914th experiment: 35 updates!
# 1915th experiment: 37 updates!
# 1916th experiment: 43 updates!
# 1917th experiment: 48 updates!
# 1918th experiment: 35 updates!
# 1919th experiment: 89 updates!
# 1920th experiment: 11 updates!
# 1921th experiment: 37 updates!
# 1922th experiment: 24 updates!
# 1923th experiment: 60 updates!
# 1924th experiment: 37 updates!
# 1925th experiment: 18 updates!
# 1926th experiment: 41 updates!
# 1927th experiment: 45 updates!
# 1928th experiment: 29 updates!
# 1929th experiment: 37 updates!
# 1930th experiment: 52 updates!
# 1931th experiment: 33 updates!
# 1932th experiment: 58 updates!
# 1933th experiment: 60 updates!
# 1934th experiment: 60 updates!
# 1935th experiment: 37 updates!
# 1936th experiment: 54 updates!
# 1937th experiment: 39 updates!
# 1938th experiment: 39 updates!
# 1939th experiment: 24 updates!
# 1940th experiment: 43 updates!
# 1941th experiment: 43 updates!
# 1942th experiment: 41 updates!
# 1943th experiment: 30 updates!
# 1944th experiment: 35 updates!
# 1945th experiment: 43 updates!
# 1946th experiment: 43 updates!
# 1947th experiment: 54 updates!
# 1948th experiment: 26 updates!
# 1949th experiment: 62 updates!
# 1950th experiment: 39 updates!
# 1951th experiment: 39 updates!
# 1952th experiment: 47 updates!
# 1953th experiment: 20 updates!
# 1954th experiment: 41 updates!
# 1955th experiment: 56 updates!
# 1956th experiment: 62 updates!
# 1957th experiment: 46 updates!
# 1958th experiment: 62 updates!
# 1959th experiment: 41 updates!
# 1960th experiment: 37 updates!
# 1961th experiment: 43 updates!
# 1962th experiment: 24 updates!
# 1963th experiment: 41 updates!
# 1964th experiment: 37 updates!
# 1965th experiment: 39 updates!
# 1966th experiment: 58 updates!
# 1967th experiment: 39 updates!
# 1968th experiment: 39 updates!
# 1969th experiment: 16 updates!
# 1970th experiment: 35 updates!
# 1971th experiment: 58 updates!
# 1972th experiment: 46 updates!
# 1973th experiment: 60 updates!
# 1974th experiment: 26 updates!
# 1975th experiment: 62 updates!
# 1976th experiment: 58 updates!
# 1977th experiment: 35 updates!
# 1978th experiment: 62 updates!
# 1979th experiment: 26 updates!
# 1980th experiment: 60 updates!
# 1981th experiment: 37 updates!
# 1982th experiment: 48 updates!
# 1983th experiment: 37 updates!
# 1984th experiment: 39 updates!
# 1985th experiment: 22 updates!
# 1986th experiment: 11 updates!
# 1987th experiment: 41 updates!
# 1988th experiment: 35 updates!
# 1989th experiment: 43 updates!
# 1990th experiment: 41 updates!
# 1991th experiment: 20 updates!
# 1992th experiment: 37 updates!
# 1993th experiment: 37 updates!
# 1994th experiment: 43 updates!
# 1995th experiment: 41 updates!
# 1996th experiment: 54 updates!
# 1997th experiment: 37 updates!
# 1998th experiment: 24 updates!
# 1999th experiment: 41 updates!

# %%
w
# Out:
# array([-3.        ,  2.30784   , -1.133837  ,  2.110653  ,  4.34285278])

# %%
t
# Out:
# 39

# %% [markdown]
# If we visit examples in fixed, pre-determined random cycles, then the average number of updates is 39.

# %% [markdown]
# ## Question 17

# %% [markdown]
# Implement a version of PLA by visiting examples in fixed, pre-determined random cycles throughout the algorithm, while changing the update rule to be
#
# $$
# \mathbf{w}_{t+1} \leftarrow \mathbf{w}_{t}+\eta y_{n(t)} \mathbf{x}_{n(t)}
# $$
#
# with $\eta=0.5$. Note that your PLA in the previous Question corresponds to $\eta=1$. Please repeat your experiment for 2000 times, each with a different random seed. What is the average number of updates before the algorithm halts?

# %%
def PLA_random_eta(X, y, eta=1.0):
    """
    PLA by visiting examples in a fixed, pre-determined random cycles
    and update the weight using the given learning rate eta with default
    value 1.0.

    Note: It repeat experiment for 2000 times.
    
    Args:
        X  : numpy array(n, d), feature matrix
        y  : numpy array(n, ), labels
        eta: double, learning rate
    Returns:
        w         : numpy array(d+1, ), final weights including bias w0
        update_cnt: the average number of updates 
    """
    T = 2000
    t_list = []
    n = X.shape[0]
    indices = np.arange(n)
    
    for i in range(T):
        # Shuffle X and y together using random indices
        np.random.shuffle(indices)  
        X = X[indices]
        y = y[indices]
        w, t = PLA_cyclic_eta(X, y, eta)
        t_list.append(t)
        print(f"{i}th experiment: {t} updates!")
    return w, int(np.mean(t_list))


def PLA_cyclic_eta(X, y, eta):
    """
    PLA by visiting examples in the naive cycle using the order of examples in the data set (X, y).
    
    Args:
        X: numpy array(n, d), feature matrix
        y: numpy array(n, ), labels
    Returns:
        w         : numpy array(d+1, ), final weights including bias w0
        update_cnt: the total number of updates 
    """
    
    n, d = X.shape
    # Add a column of ones as first column
    X = np.c_[np.ones((n, 1)), X]
    # Initialize w to 0 and add an extra zero for w0
    w = np.zeros(d + 1)
        
    # Count the number of updates
    update_cnt = 0 
    
    is_finished = 0
    correct_num = 0
    t = 0

    while not is_finished:
        x_t, y_t = X[t], y[t]
        
        if sign(w.T @ x_t) == y_t:  # Correctly classify the current example
            correct_num += 1
        else:                       # Find a mistake
            w += eta * y_t * x_t    # Correct the mistake
            update_cnt += 1         # Increment update count
            correct_num = 0         # Reset correct num to 0 to retest the new w
        if t == n - 1:              # Start the next cycle
            t = 0
        else:
            t += 1
        if correct_num == n:        # Have all examples classified correctly
            is_finished = 1
  
    return w, update_cnt

# %%
w, t = PLA_random_eta(X, y, eta=0.5)
# Out:
# Inner 1 id: 112099436544
# Inner 2 id: 112104799168
# outer id: 112099436544
# Inner 1 id: 112105377920
# Inner 2 id: 112104810896
# outer id: 112105377920
# Inner 1 id: 112099076896
# Inner 2 id: 112105493968
# outer id: 112099076896
# Inner 1 id: 112104826480
# Inner 2 id: 112105221856
# outer id: 112104826480
# Inner 1 id: 112099800608
# Inner 2 id: 112099801648
# outer id: 112099800608
# Inner 1 id: 112144826736
# Inner 2 id: 112144827056
# outer id: 112144826736
# Inner 1 id: 112105909184
# Inner 2 id: 112105906544
# outer id: 112105909184
# Inner 1 id: 112099293024
# Inner 2 id: 112099292304
# outer id: 112099293024
# Inner 1 id: 112104613248
# Inner 2 id: 112104615568
# outer id: 112104613248
# Inner 1 id: 112099238416
# Inner 2 id: 112099241216
# outer id: 112099238416
# Inner 1 id: 112129776496
# Inner 2 id: 112129774096
# outer id: 112129776496
# Inner 1 id: 112105457744
# Inner 2 id: 112105485296
# outer id: 112105457744
# Inner 1 id: 112106242656
# Inner 2 id: 112106244656
# outer id: 112106242656
# Inner 1 id: 112100014400
# Inner 2 id: 112100014960
# outer id: 112100014400
# Inner 1 id: 112100015440
# Inner 2 id: 112100013680
# outer id: 112100015440
# Inner 1 id: 112100014880
# Inner 2 id: 112100012560
# outer id: 112100014880
# Inner 1 id: 112050417712
# Inner 2 id: 112100012080
# outer id: 112050417712
# Inner 1 id: 112097361792
# Inner 2 id: 112097358352
# outer id: 112097361792
# Inner 1 id: 112097360912
# Inner 2 id: 112097359232
# outer id: 112097360912
# Inner 1 id: 112097983104
# Inner 2 id: 112097982704
# outer id: 112097983104
# Inner 1 id: 112100022832
# Inner 2 id: 112100021152
# outer id: 112100022832
# Inner 1 id: 112100022432
# Inner 2 id: 112100024032
# outer id: 112100022432
# Inner 1 id: 112104514864
# Inner 2 id: 112106337904
# outer id: 112104514864
# Inner 1 id: 112099536368
# Inner 2 id: 112099691536
# outer id: 112099536368
# Inner 1 id: 112099366432
# Inner 2 id: 112099367312
# outer id: 112099366432
# Inner 1 id: 112100054400
# Inner 2 id: 112100056640
# outer id: 112100054400
# Inner 1 id: 112106230208
# Inner 2 id: 112100054560
# outer id: 112106230208
# Inner 1 id: 112099888144
# Inner 2 id: 112105657168
# outer id: 112099888144
# Inner 1 id: 112099336800
# Inner 2 id: 112099337600
# outer id: 112099336800
# Inner 1 id: 112099336560
# Inner 2 id: 112099338160
# outer id: 112099336560
# Inner 1 id: 112139521600
# Inner 2 id: 112139519200
# outer id: 112139521600
# Inner 1 id: 112099052480
# Inner 2 id: 112099050080
# outer id: 112099052480
# Inner 1 id: 112144805936
# Inner 2 id: 112144808816
# outer id: 112144805936
# Inner 1 id: 112100060416
# Inner 2 id: 112100058816
# outer id: 112100060416
# Inner 1 id: 112100060656
# Inner 2 id: 112100060816
# outer id: 112100060656
# Inner 1 id: 112106480224
# Inner 2 id: 112106480944
# outer id: 112106480224
# Inner 1 id: 112139528432
# Inner 2 id: 112104763840
# outer id: 112139528432
# Inner 1 id: 112080297136
# Inner 2 id: 112099427872
# outer id: 112080297136
# Inner 1 id: 112105736592
# Inner 2 id: 112106852064
# outer id: 112105736592
# Inner 1 id: 112100047808
# Inner 2 id: 112100045728
# outer id: 112100047808
# Inner 1 id: 112105502560
# Inner 2 id: 112097929696
# outer id: 112105502560
# Inner 1 id: 112139497344
# Inner 2 id: 112097928416
# outer id: 112139497344
# Inner 1 id: 112105503280
# Inner 2 id: 112105621264
# outer id: 112105503280
# Inner 1 id: 112106852144
# Inner 2 id: 112106849104
# outer id: 112106852144
# Inner 1 id: 112099429152
# Inner 2 id: 112099428352
# outer id: 112099429152
# Inner 1 id: 112105194640
# Inner 2 id: 112105194800
# outer id: 112105194640
# Inner 1 id: 112139528432
# Inner 2 id: 112106533152
# outer id: 112139528432
# Inner 1 id: 112106480224
# Inner 2 id: 112139528112
# outer id: 112106480224
# Inner 1 id: 112100060656
# Inner 2 id: 112100058096
# outer id: 112100060656
# Inner 1 id: 112100058896
# Inner 2 id: 112100060416
# outer id: 112100058896
# Inner 1 id: 112100058016
# Inner 2 id: 112100059856
# outer id: 112100058016
# Inner 1 id: 112100058736
# Inner 2 id: 112100060816
# outer id: 112100058736
# Inner 1 id: 112144809216
# Inner 2 id: 112144805936
# outer id: 112144809216
# Inner 1 id: 112094866608
# Inner 2 id: 112094866768
# outer id: 112094866608
# Inner 1 id: 112099050640
# Inner 2 id: 112099052480
# outer id: 112099050640
# Inner 1 id: 112104897232
# Inner 2 id: 112104896912
# outer id: 112104897232
# Inner 1 id: 112139519200
# Inner 2 id: 112139519760
# outer id: 112139519200
# Inner 1 id: 112099102928
# Inner 2 id: 112105634352
# outer id: 112099102928
# Inner 1 id: 112099338160
# Inner 2 id: 112099339920
# outer id: 112099338160
# Inner 1 id: 112099336960
# Inner 2 id: 112099339680
# outer id: 112099336960
# Inner 1 id: 112105657168
# Inner 2 id: 112099339360
# outer id: 112105657168
# Inner 1 id: 112106232928
# Inner 2 id: 112106229968
# outer id: 112106232928
# Inner 1 id: 112099366432
# Inner 2 id: 112099536368
# outer id: 112099366432
# Inner 1 id: 112099366192
# Inner 2 id: 112099365392
# outer id: 112099366192
# Inner 1 id: 112104923824
# Inner 2 id: 112104517104
# outer id: 112104923824
# Inner 1 id: 112106337904
# Inner 2 id: 112099688816
# outer id: 112106337904
# Inner 1 id: 112097982704
# Inner 2 id: 112097982784
# outer id: 112097982704
# Inner 1 id: 112097360912
# Inner 2 id: 112097361072
# outer id: 112097360912
# Inner 1 id: 112097358352
# Inner 2 id: 112097358592
# outer id: 112097358352
# Inner 1 id: 112100053840
# Inner 2 id: 112100054560
# outer id: 112100053840
# Inner 1 id: 112100056640
# Inner 2 id: 112100055200
# outer id: 112100056640
# Inner 1 id: 112100056800
# Inner 2 id: 112100053120
# outer id: 112100056800
# Inner 1 id: 112100054160
# Inner 2 id: 112100055920
# outer id: 112100054160
# Inner 1 id: 112105044368
# Inner 2 id: 112080214976
# outer id: 112105044368
# Inner 1 id: 112105893040
# Inner 2 id: 112105890320
# outer id: 112105893040
# Inner 1 id: 112100024032
# Inner 2 id: 112106838176
# outer id: 112100024032
# Inner 1 id: 112100021152
# Inner 2 id: 112100020672
# outer id: 112100021152
# Inner 1 id: 112105176880
# Inner 2 id: 112100023072
# outer id: 112105176880
# Inner 1 id: 112100012080
# Inner 2 id: 112100014880
# outer id: 112100012080
# Inner 1 id: 112100014000
# Inner 2 id: 112100016000
# outer id: 112100014000
# Inner 1 id: 112099577328
# Inner 2 id: 112106242656
# outer id: 112099577328
# Inner 1 id: 112105485696
# Inner 2 id: 112129774096
# outer id: 112105485696
# Inner 1 id: 112099291664
# Inner 2 id: 112099292464
# outer id: 112099291664
# Inner 1 id: 112144827056
# Inner 2 id: 112099801648
# outer id: 112144827056
# Inner 1 id: 112105493968
# Inner 2 id: 112104810896
# outer id: 112105493968
# Inner 1 id: 112104847680
# Inner 2 id: 112099354464
# outer id: 112104847680
# Inner 1 id: 112099613952
# Inner 2 id: 112105543440
# outer id: 112099613952
# Inner 1 id: 112080281312
# Inner 2 id: 112080281392
# outer id: 112080281312
# Inner 1 id: 112100048208
# Inner 2 id: 112100047808
# outer id: 112100048208
# Inner 1 id: 112139495264
# Inner 2 id: 112139496224
# outer id: 112139495264
# Inner 1 id: 112105390288
# Inner 2 id: 112099125168
# outer id: 112105390288
# Inner 1 id: 112097977248
# Inner 2 id: 112097978128
# outer id: 112097977248
# Inner 1 id: 112099807280
# Inner 2 id: 112100031184
# outer id: 112099807280
# Inner 1 id: 112097372320
# Inner 2 id: 112097407264
# outer id: 112097372320
# Inner 1 id: 112104646176
# Inner 2 id: 112104645776
# outer id: 112104646176
# Inner 1 id: 112100031504
# Inner 2 id: 112100029904
# outer id: 112100031504
# Inner 1 id: 112099811120
# Inner 2 id: 112099810880
# outer id: 112099811120
# Inner 1 id: 112099125168
# Inner 2 id: 112099126208
# outer id: 112099125168
# Inner 1 id: 112098995056
# Inner 2 id: 112098994976
# outer id: 112098995056
# Inner 1 id: 112139497024
# Inner 2 id: 112139495264
# outer id: 112139497024
# Inner 1 id: 112099613952
# Inner 2 id: 112099757712
# outer id: 112099613952
# Inner 1 id: 112080280992
# Inner 2 id: 112080281312
# outer id: 112080280992
# Inner 1 id: 112105543440
# Inner 2 id: 112080280592
# outer id: 112105543440
# Inner 1 id: 112099161152
# Inner 2 id: 112104986464
# outer id: 112099161152
# Inner 1 id: 112105437104
# Inner 2 id: 112106473712
# outer id: 112105437104
# Inner 1 id: 112105534128
# Inner 2 id: 112099354464
# outer id: 112105534128
# Inner 1 id: 112104810896
# Inner 2 id: 112098665296
# outer id: 112104810896
# Inner 1 id: 112099799328
# Inner 2 id: 112099802608
# outer id: 112099799328
# Inner 1 id: 112099473008
# Inner 2 id: 112105906544
# outer id: 112099473008
# Inner 1 id: 112099576528
# Inner 2 id: 112099577328
# outer id: 112099576528
# Inner 1 id: 112129777456
# Inner 2 id: 112129774096
# outer id: 112129777456
# Inner 1 id: 112099490592
# Inner 2 id: 112099488592
# outer id: 112099490592
# Inner 1 id: 112105457744
# Inner 2 id: 112105455984
# outer id: 112105457744
# Inner 1 id: 112099292304
# Inner 2 id: 112099291664
# outer id: 112099292304
# Inner 1 id: 112105044368
# Inner 2 id: 112105496048
# outer id: 112105044368
# Inner 1 id: 112100012560
# Inner 2 id: 112100014000
# outer id: 112100012560
# Inner 1 id: 112100014960
# Inner 2 id: 112100012080
# outer id: 112100014960
# Inner 1 id: 112100015520
# Inner 2 id: 112100016000
# outer id: 112100015520
# Inner 1 id: 112100021712
# Inner 2 id: 112100014400
# outer id: 112100021712
# Inner 1 id: 112100023072
# Inner 2 id: 112100021552
# outer id: 112100023072
# Inner 1 id: 112100022832
# Inner 2 id: 112100020672
# outer id: 112100022832
# Inner 1 id: 112100047488
# Inner 2 id: 112100045888
# outer id: 112100047488
# Inner 1 id: 112100045968
# Inner 2 id: 112100045728
# outer id: 112100045968
# Inner 1 id: 112105893040
# Inner 2 id: 112100046208
# outer id: 112105893040
# Inner 1 id: 112104799168
# Inner 2 id: 112105892160
# outer id: 112104799168
# Inner 1 id: 112050417712
# Inner 2 id: 112050418912
# outer id: 112050417712
# Inner 1 id: 112104788416
# Inner 2 id: 112099684480
# outer id: 112104788416
# Inner 1 id: 112100054160
# Inner 2 id: 112100056160
# outer id: 112100054160
# Inner 1 id: 112100055440
# Inner 2 id: 112100053840
# outer id: 112100055440
# Inner 1 id: 112100055200
# Inner 2 id: 112100055600
# outer id: 112100055200
# Inner 1 id: 112100056720
# Inner 2 id: 112100056960
# outer id: 112100056720
# Inner 1 id: 112104031536
# Inner 2 id: 112097360912
# outer id: 112104031536
# Inner 1 id: 112097361072
# Inner 2 id: 112099794256
# outer id: 112097361072
# Inner 1 id: 112097982704
# Inner 2 id: 112097982944
# outer id: 112097982704
# Inner 1 id: 112099688816
# Inner 2 id: 112105326432
# outer id: 112099688816
# Inner 1 id: 112105221856
# Inner 2 id: 112105218976
# outer id: 112105221856
# Inner 1 id: 112099367312
# Inner 2 id: 112099227568
# outer id: 112099367312
# Inner 1 id: 112099436544
# Inner 2 id: 112106231168
# outer id: 112099436544
# Inner 1 id: 112105657168
# Inner 2 id: 112099338800
# outer id: 112105657168
# Inner 1 id: 112099338720
# Inner 2 id: 112099337600
# outer id: 112099338720
# Inner 1 id: 112105635312
# Inner 2 id: 112139519760
# outer id: 112105635312
# Inner 1 id: 112099739408
# Inner 2 id: 112094866768
# outer id: 112099739408
# Inner 1 id: 112100059696
# Inner 2 id: 112100060496
# outer id: 112100059696
# Inner 1 id: 112100060416
# Inner 2 id: 112100060016
# outer id: 112100060416
# Inner 1 id: 112139527952
# Inner 2 id: 112106533152
# outer id: 112139527952
# Inner 1 id: 112099428352
# Inner 2 id: 112106851984
# outer id: 112099428352
# Inner 1 id: 112097928496
# Inner 2 id: 112105160096
# outer id: 112097928496
# Inner 1 id: 112144809056
# Inner 2 id: 112144808816
# outer id: 112144809056
# Inner 1 id: 112094866768
# Inner 2 id: 112094866528
# outer id: 112094866768
# Inner 1 id: 112104895552
# Inner 2 id: 112104896912
# outer id: 112104895552
# Inner 1 id: 112099102928
# Inner 2 id: 112139519760
# outer id: 112099102928
# Inner 1 id: 112099337200
# Inner 2 id: 112099339440
# outer id: 112099337200
# Inner 1 id: 112099338960
# Inner 2 id: 112099339360
# outer id: 112099338960
# Inner 1 id: 112099337440
# Inner 2 id: 112099339920
# outer id: 112099337440
# Inner 1 id: 112106230208
# Inner 2 id: 112106229968
# outer id: 112106230208
# Inner 1 id: 112099536368
# Inner 2 id: 112099535888
# outer id: 112099536368
# Inner 1 id: 112099227568
# Inner 2 id: 112099229488
# outer id: 112099227568
# Inner 1 id: 112105218976
# Inner 2 id: 112105218576
# outer id: 112105218976
# Inner 1 id: 112099367312
# Inner 2 id: 112104517104
# outer id: 112099367312
# Inner 1 id: 112099365632
# Inner 2 id: 112099365392
# outer id: 112099365632
# Inner 1 id: 112105326432
# Inner 2 id: 112104031536
# outer id: 112105326432
# Inner 1 id: 112097982704
# Inner 2 id: 112105531952
# outer id: 112097982704
# Inner 1 id: 112099794256
# Inner 2 id: 112099712096
# outer id: 112099794256
# Inner 1 id: 112097361072
# Inner 2 id: 112104856752
# outer id: 112097361072
# Inner 1 id: 112097358592
# Inner 2 id: 112097358992
# outer id: 112097358592
# Inner 1 id: 112050243904
# Inner 2 id: 112097360912
# outer id: 112050243904
# Inner 1 id: 112100055200
# Inner 2 id: 112100056720
# outer id: 112100055200
# Inner 1 id: 112100054400
# Inner 2 id: 112100055440
# outer id: 112100054400
# Inner 1 id: 112100054560
# Inner 2 id: 112100055760
# outer id: 112100054560
# Inner 1 id: 112100055920
# Inner 2 id: 112100053120
# outer id: 112100055920
# Inner 1 id: 112099684480
# Inner 2 id: 112100056640
# outer id: 112099684480
# Inner 1 id: 112050417712
# Inner 2 id: 112099061968
# outer id: 112050417712
# Inner 1 id: 112104443216
# Inner 2 id: 112050418912
# outer id: 112104443216
# Inner 1 id: 112050530384
# Inner 2 id: 112098580400
# outer id: 112050530384
# Inner 1 id: 112105503520
# Inner 2 id: 112105502560
# outer id: 112105503520
# Inner 1 id: 112105892640
# Inner 2 id: 112105890320
# outer id: 112105892640
# Inner 1 id: 112104763840
# Inner 2 id: 112104766480
# outer id: 112104763840
# Inner 1 id: 112105409072
# Inner 2 id: 112105407952
# outer id: 112105409072
# Inner 1 id: 112099429152
# Inner 2 id: 112099428352
# outer id: 112099429152
# Inner 1 id: 112100021712
# Inner 2 id: 112100023072
# outer id: 112100021712
# Inner 1 id: 112100021872
# Inner 2 id: 112100021312
# outer id: 112100021872
# Inner 1 id: 112100020352
# Inner 2 id: 112100024032
# outer id: 112100020352
# Inner 1 id: 112106482704
# Inner 2 id: 112106480944
# outer id: 112106482704
# Inner 1 id: 112099879552
# Inner 2 id: 112100045968
# outer id: 112099879552
# Inner 1 id: 112100045728
# Inner 2 id: 112100044928
# outer id: 112100045728
# Inner 1 id: 112100014960
# Inner 2 id: 112100012560
# outer id: 112100014960
# Inner 1 id: 112100012080
# Inner 2 id: 112100013680
# outer id: 112100012080
# Inner 1 id: 112100059136
# Inner 2 id: 112100059536
# outer id: 112100059136
# Inner 1 id: 112100060496
# Inner 2 id: 112099238416
# outer id: 112100060496
# Inner 1 id: 112139528272
# Inner 2 id: 112105496048
# outer id: 112139528272
# Inner 1 id: 112106613696
# Inner 2 id: 112104607616
# outer id: 112106613696
# Inner 1 id: 112099489632
# Inner 2 id: 112099488592
# outer id: 112099489632
# Inner 1 id: 112104613248
# Inner 2 id: 112099575968
# outer id: 112104613248
# Inner 1 id: 112105908144
# Inner 2 id: 112099801648
# outer id: 112105908144
# Inner 1 id: 112099479104
# Inner 2 id: 112103866896
# outer id: 112099479104
# Inner 1 id: 112080280592
# Inner 2 id: 112080281312
# outer id: 112080280592
# Inner 1 id: 112139495264
# Inner 2 id: 112139497264
# outer id: 112139495264
# Inner 1 id: 112099810880
# Inner 2 id: 112099807280
# outer id: 112099810880
# Inner 1 id: 112097978608
# Inner 2 id: 112105390288
# outer id: 112097978608
# Inner 1 id: 112097325504
# Inner 2 id: 112131952768
# outer id: 112097325504
# Inner 1 id: 112104613248
# Inner 2 id: 112104986464
# outer id: 112104613248
# Inner 1 id: 112104694288
# Inner 2 id: 112144827056
# outer id: 112104694288
# Inner 1 id: 112105485296
# Inner 2 id: 112105909184
# outer id: 112105485296
# Inner 1 id: 112129777456
# Inner 2 id: 112129776816
# outer id: 112129777456
# Inner 1 id: 112099490352
# Inner 2 id: 112099490592
# outer id: 112099490352
# Inner 1 id: 112105455984
# Inner 2 id: 112105457744
# outer id: 112105455984
# Inner 1 id: 112099293024
# Inner 2 id: 112099291664
# outer id: 112099293024
# Inner 1 id: 112139528352
# Inner 2 id: 112139528432
# outer id: 112139528352
# Inner 1 id: 112099241216
# Inner 2 id: 112099238816
# outer id: 112099241216
# Inner 1 id: 112100013120
# Inner 2 id: 112100014960
# outer id: 112100013120
# Inner 1 id: 112100015200
# Inner 2 id: 112100014000
# outer id: 112100015200
# Inner 1 id: 112100014400
# Inner 2 id: 112100015200
# outer id: 112100014400
# Inner 1 id: 112100059136
# Inner 2 id: 112100060496
# outer id: 112100059136
# Inner 1 id: 112100057856
# Inner 2 id: 112100060176
# outer id: 112100057856
# Inner 1 id: 112100057376
# Inner 2 id: 112100060016
# outer id: 112100057376
# Inner 1 id: 112105377920
# Inner 2 id: 112100059536
# outer id: 112105377920
# Inner 1 id: 112100046048
# Inner 2 id: 112100048048
# outer id: 112100046048
# Inner 1 id: 112100044928
# Inner 2 id: 112100047488
# outer id: 112100044928
# Inner 1 id: 112105196080
# Inner 2 id: 112100046208
# outer id: 112105196080
# Inner 1 id: 112106480944
# Inner 2 id: 112106482704
# outer id: 112106480944
# Inner 1 id: 112100021872
# Inner 2 id: 112100020352
# outer id: 112100021872
# Inner 1 id: 112100023792
# Inner 2 id: 112100021712
# outer id: 112100023792
# Inner 1 id: 112100020672
# Inner 2 id: 112100021312
# outer id: 112100020672
# Inner 1 id: 112099429152
# Inner 2 id: 112097372320
# outer id: 112099429152
# Inner 1 id: 112144794848
# Inner 2 id: 112099428352
# outer id: 112144794848
# Inner 1 id: 112099799568
# Inner 2 id: 112099801648
# outer id: 112099799568
# Inner 1 id: 112106851984
# Inner 2 id: 112106852064
# outer id: 112106851984
# Inner 1 id: 112097407184
# Inner 2 id: 112106852144
# outer id: 112097407184
# Inner 1 id: 112099640064
# Inner 2 id: 112104766480
# outer id: 112099640064
# Inner 1 id: 112105892160
# Inner 2 id: 112105892640
# outer id: 112105892160
# Inner 1 id: 112080297136
# Inner 2 id: 112080297296
# outer id: 112080297136
# Inner 1 id: 112099684480
# Inner 2 id: 112097922304
# outer id: 112099684480
# Inner 1 id: 112100031504
# Inner 2 id: 112100031264
# outer id: 112100031504
# Inner 1 id: 112098579680
# Inner 2 id: 112098580160
# outer id: 112098579680
# Inner 1 id: 112099807920
# Inner 2 id: 112099810880
# outer id: 112099807920
# Inner 1 id: 112050418912
# Inner 2 id: 112104799168
# outer id: 112050418912
# Inner 1 id: 112105174800
# Inner 2 id: 112099064768
# outer id: 112105174800
# Inner 1 id: 112105974800
# Inner 2 id: 112106242656
# outer id: 112105974800
# Inner 1 id: 112098995056
# Inner 2 id: 112080281392
# outer id: 112098995056
# Inner 1 id: 112100056640
# Inner 2 id: 112100053840
# outer id: 112100056640
# Inner 1 id: 112100055600
# Inner 2 id: 112100053760
# outer id: 112100055600
# Inner 1 id: 112139496864
# Inner 2 id: 112139497344
# outer id: 112139496864
# Inner 1 id: 112097928496
# Inner 2 id: 112097358592
# outer id: 112097928496
# Inner 1 id: 112104856752
# Inner 2 id: 112099712096
# outer id: 112104856752
# Inner 1 id: 112106202016
# Inner 2 id: 112104031536
# outer id: 112106202016
# Inner 1 id: 112104517104
# Inner 2 id: 112105218576
# outer id: 112104517104
# Inner 1 id: 112106230208
# Inner 2 id: 112106229968
# outer id: 112106230208
# Inner 1 id: 112099339360
# Inner 2 id: 112099340080
# outer id: 112099339360
# Inner 1 id: 112139521600
# Inner 2 id: 112104897232
# outer id: 112139521600
# Inner 1 id: 112094866688
# Inner 2 id: 112105634352
# outer id: 112094866688
# Inner 1 id: 112106231168
# Inner 2 id: 112106231808
# outer id: 112106231168
# Inner 1 id: 112099535888
# Inner 2 id: 112099535488
# outer id: 112099535888
# Inner 1 id: 112105736592
# Inner 2 id: 112099229088
# outer id: 112105736592
# Inner 1 id: 112099366192
# Inner 2 id: 112099367872
# outer id: 112099366192
# Inner 1 id: 112097982944
# Inner 2 id: 112106362080
# outer id: 112097982944
# Inner 1 id: 112097359232
# Inner 2 id: 112097360912
# outer id: 112097359232
# Inner 1 id: 112097358592
# Inner 2 id: 112097358352
# outer id: 112097358592
# Inner 1 id: 112139496864
# Inner 2 id: 112105974800
# outer id: 112139496864
# Inner 1 id: 112139497344
# Inner 2 id: 112139497264
# outer id: 112139497344
# Inner 1 id: 112080280352
# Inner 2 id: 112098995056
# outer id: 112080280352
# Inner 1 id: 112105634352
# Inner 2 id: 112080281312
# outer id: 112105634352
# Inner 1 id: 112105176880
# Inner 2 id: 112105174800
# outer id: 112105176880
# Inner 1 id: 112099612912
# Inner 2 id: 112106243216
# outer id: 112099612912
# Inner 1 id: 112050418912
# Inner 2 id: 112099774512
# outer id: 112050418912
# Inner 1 id: 112099064768
# Inner 2 id: 112099061968
# outer id: 112099064768
# Inner 1 id: 112104799168
# Inner 2 id: 112104798688
# outer id: 112104799168
# Inner 1 id: 112099807920
# Inner 2 id: 112099809520
# outer id: 112099807920
# Inner 1 id: 112105802288
# Inner 2 id: 112105621264
# outer id: 112105802288
# Inner 1 id: 112098580400
# Inner 2 id: 112098580160
# outer id: 112098580400
# Inner 1 id: 112100031504
# Inner 2 id: 112100028624
# outer id: 112100031504
# Inner 1 id: 112100029904
# Inner 2 id: 112100032224
# outer id: 112100029904
# Inner 1 id: 112097407264
# Inner 2 id: 112104614848
# outer id: 112097407264
# Inner 1 id: 112099051360
# Inner 2 id: 112097407184
# outer id: 112099051360
# Inner 1 id: 112105503280
# Inner 2 id: 112105502560
# outer id: 112105503280
# Inner 1 id: 112100056720
# Inner 2 id: 112100055600
# outer id: 112100056720
# Inner 1 id: 112100056960
# Inner 2 id: 112100054800
# outer id: 112100056960
# Inner 1 id: 112100055760
# Inner 2 id: 112100054160
# outer id: 112100055760
# Inner 1 id: 112100055040
# Inner 2 id: 112100056160
# outer id: 112100055040
# Inner 1 id: 112105892640
# Inner 2 id: 112105891600
# outer id: 112105892640
# Inner 1 id: 112104766480
# Inner 2 id: 112104763840
# outer id: 112104766480
# Inner 1 id: 112106339984
# Inner 2 id: 112106339184
# outer id: 112106339984
# Inner 1 id: 112139519760
# Inner 2 id: 112139521600
# outer id: 112139519760
# Inner 1 id: 112106849824
# Inner 2 id: 112106849104
# outer id: 112106849824
# Inner 1 id: 112080214976
# Inner 2 id: 112099799568
# outer id: 112080214976
# Inner 1 id: 112099436544
# Inner 2 id: 112105407952
# outer id: 112099436544
# Inner 1 id: 112099429152
# Inner 2 id: 112099436704
# outer id: 112099429152
# Inner 1 id: 112105534128
# Inner 2 id: 112105112960
# outer id: 112105534128
# Inner 1 id: 112100021552
# Inner 2 id: 112100021872
# outer id: 112100021552
# Inner 1 id: 112100024032
# Inner 2 id: 112100022432
# outer id: 112100024032
# Inner 1 id: 112106838176
# Inner 2 id: 112104825840
# outer id: 112106838176
# Inner 1 id: 112099592032
# Inner 2 id: 112105044368
# outer id: 112099592032
# Inner 1 id: 112100048768
# Inner 2 id: 112100048208
# outer id: 112100048768
# Inner 1 id: 112100060656
# Inner 2 id: 112100057376
# outer id: 112100060656
# Inner 1 id: 112100060176
# Inner 2 id: 112100058656
# outer id: 112100060176
# Inner 1 id: 112100014000
# Inner 2 id: 112100013280
# outer id: 112100014000
# Inner 1 id: 112099238176
# Inner 2 id: 112139528112
# outer id: 112099238176
# Inner 1 id: 112105457744
# Inner 2 id: 112099490592
# outer id: 112105457744
# Inner 1 id: 112104986464
# Inner 2 id: 112139507312
# outer id: 112104986464
# Inner 1 id: 112099336560
# Inner 2 id: 112105390288
# outer id: 112099336560
# Inner 1 id: 112105496048
# Inner 2 id: 112139528432
# outer id: 112105496048
# Inner 1 id: 112099238416
# Inner 2 id: 112099238176
# outer id: 112099238416
# Inner 1 id: 112100014960
# Inner 2 id: 112100014000
# outer id: 112100014960
# Inner 1 id: 112100060176
# Inner 2 id: 112106838176
# outer id: 112100060176
# Inner 1 id: 112100060816
# Inner 2 id: 112100058976
# outer id: 112100060816
# Inner 1 id: 112100058656
# Inner 2 id: 112100060496
# outer id: 112100058656
# Inner 1 id: 112100061056
# Inner 2 id: 112100058096
# outer id: 112100061056
# Inner 1 id: 112100045728
# Inner 2 id: 112100048768
# outer id: 112100045728
# Inner 1 id: 112100046208
# Inner 2 id: 112100047168
# outer id: 112100046208
# Inner 1 id: 112100045888
# Inner 2 id: 112100047808
# outer id: 112100045888
# Inner 1 id: 112105194800
# Inner 2 id: 112105194640
# outer id: 112105194800
# Inner 1 id: 112106480224
# Inner 2 id: 112106465680
# outer id: 112106480224
# Inner 1 id: 112099102928
# Inner 2 id: 112099446496
# outer id: 112099102928
# Inner 1 id: 112100020352
# Inner 2 id: 112100021152
# outer id: 112100020352
# Inner 1 id: 112100021712
# Inner 2 id: 112100023792
# outer id: 112100021712
# Inner 1 id: 112104896912
# Inner 2 id: 112104897232
# outer id: 112104896912
# Inner 1 id: 112105114960
# Inner 2 id: 112106715456
# outer id: 112105114960
# Inner 1 id: 112099430272
# Inner 2 id: 112099428352
# outer id: 112099430272
# Inner 1 id: 112099436704
# Inner 2 id: 112099436544
# outer id: 112099436704
# Inner 1 id: 112105407952
# Inner 2 id: 112094866688
# outer id: 112105407952
# Inner 1 id: 112099802608
# Inner 2 id: 112105409072
# outer id: 112099802608
# Inner 1 id: 112104443216
# Inner 2 id: 112099799568
# outer id: 112104443216
# Inner 1 id: 112106852064
# Inner 2 id: 112106851984
# outer id: 112106852064
# Inner 1 id: 112050530384
# Inner 2 id: 112105326432
# outer id: 112050530384
# Inner 1 id: 112104766480
# Inner 2 id: 112105272464
# outer id: 112104766480
# Inner 1 id: 112139507312
# Inner 2 id: 112104765840
# outer id: 112139507312
# Inner 1 id: 112105891600
# Inner 2 id: 112105893040
# outer id: 112105891600
# Inner 1 id: 112106339184
# Inner 2 id: 112106339984
# outer id: 112106339184
# Inner 1 id: 112100055040
# Inner 2 id: 112100053280
# outer id: 112100055040
# Inner 1 id: 112100056160
# Inner 2 id: 112100056000
# outer id: 112100056160
# Inner 1 id: 112100056800
# Inner 2 id: 112100054160
# outer id: 112100056800
# Inner 1 id: 112100055600
# Inner 2 id: 112100055920
# outer id: 112100055600
# Inner 1 id: 112104694288
# Inner 2 id: 112100055200
# outer id: 112104694288
# Inner 1 id: 112099052480
# Inner 2 id: 112099051360
# outer id: 112099052480
# Inner 1 id: 112097407184
# Inner 2 id: 112097407264
# outer id: 112097407184
# Inner 1 id: 112104607616
# Inner 2 id: 112104606496
# outer id: 112104607616
# Inner 1 id: 112104614848
# Inner 2 id: 112104613248
# outer id: 112104614848
# Inner 1 id: 112097922784
# Inner 2 id: 112097922304
# outer id: 112097922784
# Inner 1 id: 112105906624
# Inner 2 id: 112100031504
# outer id: 112105906624
# Inner 1 id: 112099640064
# Inner 2 id: 112129776816
# outer id: 112099640064
# Inner 1 id: 112098580160
# Inner 2 id: 112105621264
# outer id: 112098580160
# Inner 1 id: 112104799168
# Inner 2 id: 112099684480
# outer id: 112104799168
# Inner 1 id: 112099125168
# Inner 2 id: 112099611232
# outer id: 112099125168
# Inner 1 id: 112105635312
# Inner 2 id: 112080280992
# outer id: 112105635312
# Inner 1 id: 112139494944
# Inner 2 id: 112105974800
# outer id: 112139494944
# Inner 1 id: 112097358992
# Inner 2 id: 112097982704
# outer id: 112097358992
# Inner 1 id: 112099367312
# Inner 2 id: 112099365392
# outer id: 112099367312
# Inner 1 id: 112099535488
# Inner 2 id: 112106231168
# outer id: 112099535488
# Inner 1 id: 112099338160
# Inner 2 id: 112099339920
# outer id: 112099338160
# Inner 1 id: 112099337760
# Inner 2 id: 112099337200
# outer id: 112099337760
# Inner 1 id: 112106533152
# Inner 2 id: 112099739408
# outer id: 112106533152
# Inner 1 id: 112097978128
# Inner 2 id: 112097979568
# outer id: 112097978128
# Inner 1 id: 112104645776
# Inner 2 id: 112097977248
# outer id: 112104645776
# Inner 1 id: 112105160096
# Inner 2 id: 112104856752
# outer id: 112105160096
# Inner 1 id: 112144809216
# Inner 2 id: 112144808816
# outer id: 112144809216
# Inner 1 id: 112050243904
# Inner 2 id: 112106362080
# outer id: 112050243904
# Inner 1 id: 112099712896
# Inner 2 id: 112099229488
# outer id: 112099712896
# Inner 1 id: 112105631872
# Inner 2 id: 112105635312
# outer id: 112105631872
# Inner 1 id: 112080281312
# Inner 2 id: 112080281392
# outer id: 112080281312
# Inner 1 id: 112104798688
# Inner 2 id: 112104799168
# outer id: 112104798688
# Inner 1 id: 112099762704
# Inner 2 id: 112099640064
# outer id: 112099762704
# Inner 1 id: 112099061968
# Inner 2 id: 112106243216
# outer id: 112099061968
# Inner 1 id: 112099807280
# Inner 2 id: 112099807920
# outer id: 112099807280
# Inner 1 id: 112106202016
# Inner 2 id: 112106204336
# outer id: 112106202016
# Inner 1 id: 112129777456
# Inner 2 id: 112098581680
# outer id: 112129777456
# Inner 1 id: 112105802288
# Inner 2 id: 112129774096
# outer id: 112105802288
# Inner 1 id: 112097922864
# Inner 2 id: 112097922784
# outer id: 112097922864
# Inner 1 id: 112105485696
# Inner 2 id: 112099631632
# outer id: 112105485696
# Inner 1 id: 112106251168
# Inner 2 id: 112099294064
# outer id: 112106251168
# Inner 1 id: 112104615568
# Inner 2 id: 112104613248
# outer id: 112104615568
# Inner 1 id: 112104607616
# Inner 2 id: 112099823248
# outer id: 112104607616
# Inner 1 id: 112097407184
# Inner 2 id: 112144826736
# outer id: 112097407184
# Inner 1 id: 112099161152
# Inner 2 id: 112105543440
# outer id: 112099161152
# Inner 1 id: 112105503520
# Inner 2 id: 112105502560
# outer id: 112105503520
# Inner 1 id: 112106231808
# Inner 2 id: 112105218576
# outer id: 112106231808
# Inner 1 id: 112106230208
# Inner 2 id: 112106229968
# outer id: 112106230208
# Inner 1 id: 112139506352
# Inner 2 id: 112105906544
# outer id: 112139506352
# Inner 1 id: 112100056800
# Inner 2 id: 112100055600
# outer id: 112100056800
# Inner 1 id: 112100055920
# Inner 2 id: 112100056160
# outer id: 112100055920
# Inner 1 id: 112100054800
# Inner 2 id: 112100056720
# outer id: 112100054800
# Inner 1 id: 112100056960
# Inner 2 id: 112100054560
# outer id: 112100056960
# Inner 1 id: 112106339984
# Inner 2 id: 112106339184
# outer id: 112106339984
# Inner 1 id: 112104653808
# Inner 2 id: 112106336304
# outer id: 112104653808
# Inner 1 id: 112097929696
# Inner 2 id: 112097928496
# outer id: 112097929696
# Inner 1 id: 112105892640
# Inner 2 id: 112105893040
# outer id: 112105892640
# Inner 1 id: 112099368672
# Inner 2 id: 112099366432
# outer id: 112099368672
# Inner 1 id: 112099337760
# Inner 2 id: 112099367872
# outer id: 112099337760
# Inner 1 id: 112099336560
# Inner 2 id: 112099339200
# outer id: 112099336560
# Inner 1 id: 112099337600
# Inner 2 id: 112099339360
# outer id: 112099337600
# Inner 1 id: 112099339680
# Inner 2 id: 112099338720
# outer id: 112099339680
# Inner 1 id: 112104443216
# Inner 2 id: 112105272464
# outer id: 112104443216
# Inner 1 id: 112097983104
# Inner 2 id: 112097982784
# outer id: 112097983104
# Inner 1 id: 112100031264
# Inner 2 id: 112100032224
# outer id: 112100031264
# Inner 1 id: 112106852144
# Inner 2 id: 112099802608
# outer id: 112106852144
# Inner 1 id: 112105112960
# Inner 2 id: 112144795888
# outer id: 112105112960
# Inner 1 id: 112139496864
# Inner 2 id: 112097361072
# outer id: 112139496864
# Inner 1 id: 112094866688
# Inner 2 id: 112099436704
# outer id: 112094866688
# Inner 1 id: 112099426752
# Inner 2 id: 112099429152
# outer id: 112099426752
# Inner 1 id: 112104895552
# Inner 2 id: 112100023792
# outer id: 112104895552
# Inner 1 id: 112099446496
# Inner 2 id: 112106482704
# outer id: 112099446496
# Inner 1 id: 112100044928
# Inner 2 id: 112100047168
# outer id: 112100044928
# Inner 1 id: 112100059136
# Inner 2 id: 112100060416
# outer id: 112100059136
# Inner 1 id: 112100059696
# Inner 2 id: 112100058976
# outer id: 112100059696
# Inner 1 id: 112139528272
# Inner 2 id: 112131952768
# outer id: 112139528272
# Inner 1 id: 112100047088
# Inner 2 id: 112100045968
# outer id: 112100047088
# Inner 1 id: 112104826480
# Inner 2 id: 112105196080
# outer id: 112104826480
# Inner 1 id: 112100022432
# Inner 2 id: 112100021552
# outer id: 112100022432
# Inner 1 id: 112100023792
# Inner 2 id: 112100022832
# outer id: 112100023792
# Inner 1 id: 112099428352
# Inner 2 id: 112099426752
# outer id: 112099428352
# Inner 1 id: 112094866768
# Inner 2 id: 112094866608
# outer id: 112094866768
# Inner 1 id: 112097370960
# Inner 2 id: 112097372320
# outer id: 112097370960
# Inner 1 id: 112105112960
# Inner 2 id: 112105677168
# outer id: 112105112960
# Inner 1 id: 112139496944
# Inner 2 id: 112139494944
# outer id: 112139496944
# Inner 1 id: 112144795888
# Inner 2 id: 112144794848
# outer id: 112144795888
# Inner 1 id: 112106852144
# Inner 2 id: 112106849824
# outer id: 112106852144
# Inner 1 id: 112099757712
# Inner 2 id: 112099064768
# outer id: 112099757712
# Inner 1 id: 112100031504
# Inner 2 id: 112100028624
# outer id: 112100031504
# Inner 1 id: 112097982944
# Inner 2 id: 112097983104
# outer id: 112097982944
# Inner 1 id: 112139519760
# Inner 2 id: 112139521600
# outer id: 112139519760
# Inner 1 id: 112105271744
# Inner 2 id: 112105272464
# outer id: 112105271744
# Inner 1 id: 112104810896
# Inner 2 id: 112104766480
# outer id: 112104810896
# Inner 1 id: 112099338960
# Inner 2 id: 112099337200
# outer id: 112099338960
# Inner 1 id: 112099338720
# Inner 2 id: 112099337760
# outer id: 112099338720
# Inner 1 id: 112099338480
# Inner 2 id: 112099337440
# outer id: 112099338480
# Inner 1 id: 112106412672
# Inner 2 id: 112099338160
# outer id: 112106412672
# Inner 1 id: 112099366192
# Inner 2 id: 112099367872
# outer id: 112099366192
# Inner 1 id: 112104986464
# Inner 2 id: 112099076896
# outer id: 112104986464
# Inner 1 id: 112105890320
# Inner 2 id: 112105892640
# outer id: 112105890320
# Inner 1 id: 112099535488
# Inner 2 id: 112097929696
# outer id: 112099535488
# Inner 1 id: 112106339184
# Inner 2 id: 112106339984
# outer id: 112106339184
# Inner 1 id: 112097325504
# Inner 2 id: 112106337904
# outer id: 112097325504
# Inner 1 id: 112099240656
# Inner 2 id: 112099238816
# outer id: 112099240656
# Inner 1 id: 112100054800
# Inner 2 id: 112100056960
# outer id: 112100054800
# Inner 1 id: 112100056640
# Inner 2 id: 112100054560
# outer id: 112100056640
# Inner 1 id: 112100053120
# Inner 2 id: 112100053840
# outer id: 112100053120
# Inner 1 id: 112100053760
# Inner 2 id: 112100055600
# outer id: 112100053760
# Inner 1 id: 112099799568
# Inner 2 id: 112099802448
# outer id: 112099799568
# Inner 1 id: 112100015440
# Inner 2 id: 112099802608
# outer id: 112100015440
# Inner 1 id: 112100012080
# Inner 2 id: 112100015520
# outer id: 112100012080
# Inner 1 id: 112099161152
# Inner 2 id: 112100014960
# outer id: 112099161152
# Inner 1 id: 112106230208
# Inner 2 id: 112106231808
# outer id: 112106230208
# Inner 1 id: 112097358352
# Inner 2 id: 112097358992
# outer id: 112097358352
# Inner 1 id: 112105218576
# Inner 2 id: 112105503280
# outer id: 112105218576
# Inner 1 id: 112099051360
# Inner 2 id: 112105531952
# outer id: 112099051360
# Inner 1 id: 112100060416
# Inner 2 id: 112100060656
# outer id: 112100060416
# Inner 1 id: 112106251168
# Inner 2 id: 112097407264
# outer id: 112106251168
# Inner 1 id: 112099688816
# Inner 2 id: 112099294064
# outer id: 112099688816
# Inner 1 id: 112097921664
# Inner 2 id: 112097922784
# outer id: 112097921664
# Inner 1 id: 112129774096
# Inner 2 id: 112129776816
# outer id: 112129774096
# Inner 1 id: 112105621264
# Inner 2 id: 112099807920
# outer id: 112105621264
# Inner 1 id: 112099640064
# Inner 2 id: 112050418352
# outer id: 112099640064
# Inner 1 id: 112080280992
# Inner 2 id: 112105635312
# outer id: 112080280992
# Inner 1 id: 112106362080
# Inner 2 id: 112104517104
# outer id: 112106362080
# Inner 1 id: 112104856752
# Inner 2 id: 112097977328
# outer id: 112104856752
# Inner 1 id: 112099490352
# Inner 2 id: 112099489232
# outer id: 112099490352
# Inner 1 id: 112104646976
# Inner 2 id: 112104645776
# outer id: 112104646976
# Inner 1 id: 112104674528
# Inner 2 id: 112099931920
# outer id: 112104674528
# Inner 1 id: 112104645776
# Inner 2 id: 112104645616
# outer id: 112104645776
# Inner 1 id: 112099490592
# Inner 2 id: 112099489232
# outer id: 112099490592
# Inner 1 id: 112105621264
# Inner 2 id: 112099125168
# outer id: 112105621264
# Inner 1 id: 112104517104
# Inner 2 id: 112104514864
# outer id: 112104517104
# Inner 1 id: 112099322256
# Inner 2 id: 112105974800
# outer id: 112099322256
# Inner 1 id: 112106244656
# Inner 2 id: 112106204336
# outer id: 112106244656
# Inner 1 id: 112099809520
# Inner 2 id: 112099811120
# outer id: 112099809520
# Inner 1 id: 112098579680
# Inner 2 id: 112098580160
# outer id: 112098579680
# Inner 1 id: 112099631632
# Inner 2 id: 112129774096
# outer id: 112099631632
# Inner 1 id: 112099027264
# Inner 2 id: 112097922304
# outer id: 112099027264
# Inner 1 id: 112099292304
# Inner 2 id: 112105485296
# outer id: 112099292304
# Inner 1 id: 112104606496
# Inner 2 id: 112099294064
# outer id: 112104606496
# Inner 1 id: 112080297136
# Inner 2 id: 112099691536
# outer id: 112080297136
# Inner 1 id: 112144827216
# Inner 2 id: 112104613248
# outer id: 112144827216
# Inner 1 id: 112105542720
# Inner 2 id: 112105531952
# outer id: 112105542720
# Inner 1 id: 112105502560
# Inner 2 id: 112099879552
# outer id: 112105502560
# Inner 1 id: 112097361072
# Inner 2 id: 112097360912
# outer id: 112097361072
# Inner 1 id: 112097359232
# Inner 2 id: 112097358992
# outer id: 112097359232
# Inner 1 id: 112100057376
# Inner 2 id: 112100059696
# outer id: 112100057376
# Inner 1 id: 112100057856
# Inner 2 id: 112100060176
# outer id: 112100057856
# Inner 1 id: 112100060496
# Inner 2 id: 112100059136
# outer id: 112100060496
# Inner 1 id: 112106231968
# Inner 2 id: 112106232928
# outer id: 112106231968
# Inner 1 id: 112105906624
# Inner 2 id: 112106229968
# outer id: 112105906624
# Inner 1 id: 112105218576
# Inner 2 id: 112105909184
# outer id: 112105218576
# Inner 1 id: 112099801648
# Inner 2 id: 112105218976
# outer id: 112099801648
# Inner 1 id: 112097979568
# Inner 2 id: 112099799568
# outer id: 112097979568
# Inner 1 id: 112097978608
# Inner 2 id: 112097977328
# outer id: 112097978608
# Inner 1 id: 112080281312
# Inner 2 id: 112080280992
# outer id: 112080281312
# Inner 1 id: 112100012560
# Inner 2 id: 112080280352
# outer id: 112100012560
# Inner 1 id: 112100014000
# Inner 2 id: 112100014960
# outer id: 112100014000
# Inner 1 id: 112100013280
# Inner 2 id: 112100015200
# outer id: 112100013280
# Inner 1 id: 112099052480
# Inner 2 id: 112099051360
# outer id: 112099052480
# Inner 1 id: 112100053760
# Inner 2 id: 112100056160
# outer id: 112100053760
# Inner 1 id: 112100055440
# Inner 2 id: 112100056640
# outer id: 112100055440
# Inner 1 id: 112100054160
# Inner 2 id: 112100055920
# outer id: 112100054160
# Inner 1 id: 112100056960
# Inner 2 id: 112100056720
# outer id: 112100056960
# Inner 1 id: 112099238976
# Inner 2 id: 112099240656
# outer id: 112099238976
# Inner 1 id: 112105736592
# Inner 2 id: 112105493968
# outer id: 112105736592
# Inner 1 id: 112106336304
# Inner 2 id: 112099700288
# outer id: 112106336304
# Inner 1 id: 112099473008
# Inner 2 id: 112099535488
# outer id: 112099473008
# Inner 1 id: 112105455984
# Inner 2 id: 112099712096
# outer id: 112105455984
# Inner 1 id: 112105892640
# Inner 2 id: 112105891600
# outer id: 112105892640
# Inner 1 id: 112144809216
# Inner 2 id: 112099366432
# outer id: 112144809216
# Inner 1 id: 112104653808
# Inner 2 id: 112105634352
# outer id: 112104653808
# Inner 1 id: 112099339680
# Inner 2 id: 112099338720
# outer id: 112099339680
# Inner 1 id: 112099336960
# Inner 2 id: 112099339360
# outer id: 112099336960
# Inner 1 id: 112099336400
# Inner 2 id: 112104766480
# outer id: 112099336400
# Inner 1 id: 112104788416
# Inner 2 id: 112139520880
# outer id: 112104788416
# Inner 1 id: 112100029904
# Inner 2 id: 112106849104
# outer id: 112100029904
# Inner 1 id: 112144797328
# Inner 2 id: 112139494944
# outer id: 112144797328
# Inner 1 id: 112106715936
# Inner 2 id: 112094866608
# outer id: 112106715936
# Inner 1 id: 112100020352
# Inner 2 id: 112100024032
# outer id: 112100020352
# Inner 1 id: 112105194800
# Inner 2 id: 112100048208
# outer id: 112105194800
# Inner 1 id: 112099592032
# Inner 2 id: 112099931440
# outer id: 112099592032
# Inner 1 id: 112099938832
# Inner 2 id: 112105414944
# outer id: 112099938832
# Inner 1 id: 112104664320
# Inner 2 id: 112105472128
# outer id: 112104664320
# Inner 1 id: 112144797328
# Inner 2 id: 112097372320
# outer id: 112144797328
# Inner 1 id: 112099064768
# Inner 2 id: 112105114960
# outer id: 112099064768
# Inner 1 id: 112106852064
# Inner 2 id: 112106851984
# outer id: 112106852064
# Inner 1 id: 112100028704
# Inner 2 id: 112100029504
# outer id: 112100028704
# Inner 1 id: 112139520880
# Inner 2 id: 112139521600
# outer id: 112139520880
# Inner 1 id: 112104766480
# Inner 2 id: 112104765840
# outer id: 112104766480
# Inner 1 id: 112105271744
# Inner 2 id: 112104653808
# outer id: 112105271744
# Inner 1 id: 112099339680
# Inner 2 id: 112099336960
# outer id: 112099339680
# Inner 1 id: 112099338160
# Inner 2 id: 112099337600
# outer id: 112099338160
# Inner 1 id: 112099340080
# Inner 2 id: 112099337200
# outer id: 112099340080
# Inner 1 id: 112099338720
# Inner 2 id: 112099338800
# outer id: 112099338720
# Inner 1 id: 112105635312
# Inner 2 id: 112099612912
# outer id: 112105635312
# Inner 1 id: 112099368672
# Inner 2 id: 112105631872
# outer id: 112099368672
# Inner 1 id: 112099367872
# Inner 2 id: 112099367312
# outer id: 112099367872
# Inner 1 id: 112144809216
# Inner 2 id: 112105457744
# outer id: 112144809216
# Inner 1 id: 112099794256
# Inner 2 id: 112106412672
# outer id: 112099794256
# Inner 1 id: 112105891600
# Inner 2 id: 112105892640
# outer id: 112105891600
# Inner 1 id: 112099712096
# Inner 2 id: 112099712896
# outer id: 112099712096
# Inner 1 id: 112099536368
# Inner 2 id: 112099535888
# outer id: 112099536368
# Inner 1 id: 112105701504
# Inner 2 id: 112139527952
# outer id: 112105701504
# Inner 1 id: 112106473712
# Inner 2 id: 112099593152
# outer id: 112106473712
# Inner 1 id: 112099102928
# Inner 2 id: 112106336304
# outer id: 112099102928
# Inner 1 id: 112105174800
# Inner 2 id: 112105176880
# outer id: 112105174800
# Inner 1 id: 112100055440
# Inner 2 id: 112100054160
# outer id: 112100055440
# Inner 1 id: 112100054560
# Inner 2 id: 112100055760
# outer id: 112100054560
# Inner 1 id: 112100055600
# Inner 2 id: 112100056000
# outer id: 112100055600
# Inner 1 id: 112100056160
# Inner 2 id: 112100055200
# outer id: 112100056160
# Inner 1 id: 112099051360
# Inner 2 id: 112099050080
# outer id: 112099051360
# Inner 1 id: 112104847680
# Inner 2 id: 112104895552
# outer id: 112104847680
# Inner 1 id: 112100014000
# Inner 2 id: 112100013280
# outer id: 112100014000
# Inner 1 id: 112100016000
# Inner 2 id: 112100013120
# outer id: 112100016000
# Inner 1 id: 112100013680
# Inner 2 id: 112100014960
# outer id: 112100013680
# Inner 1 id: 112099429152
# Inner 2 id: 112139497264
# outer id: 112099429152
# Inner 1 id: 112099739408
# Inner 2 id: 112099739728
# outer id: 112099739408
# Inner 1 id: 112080280992
# Inner 2 id: 112080280352
# outer id: 112080280992
# Inner 1 id: 112097979568
# Inner 2 id: 112097977328
# outer id: 112097979568
# Inner 1 id: 112105437104
# Inner 2 id: 112099799328
# outer id: 112105437104
# Inner 1 id: 112139506352
# Inner 2 id: 112099238976
# outer id: 112139506352
# Inner 1 id: 112144826736
# Inner 2 id: 112105908144
# outer id: 112144826736
# Inner 1 id: 112106715936
# Inner 2 id: 112105044368
# outer id: 112106715936
# Inner 1 id: 112106230208
# Inner 2 id: 112106231808
# outer id: 112106230208
# Inner 1 id: 112100048208
# Inner 2 id: 112100047808
# outer id: 112100048208
# Inner 1 id: 112100021712
# Inner 2 id: 112100022832
# outer id: 112100021712
# Inner 1 id: 112106482704
# Inner 2 id: 112106480224
# outer id: 112106482704
# Inner 1 id: 112100057856
# Inner 2 id: 112100057376
# outer id: 112100057856
# Inner 1 id: 112100060816
# Inner 2 id: 112100060656
# outer id: 112100060816
# Inner 1 id: 112097358592
# Inner 2 id: 112097361792
# outer id: 112097358592
# Inner 1 id: 112099161152
# Inner 2 id: 112099823248
# outer id: 112099161152
# Inner 1 id: 112104694288
# Inner 2 id: 112099294064
# outer id: 112104694288
# Inner 1 id: 112097922784
# Inner 2 id: 112097921664
# outer id: 112097922784
# Inner 1 id: 112106243216
# Inner 2 id: 112105974800
# outer id: 112106243216
# Inner 1 id: 112129777456
# Inner 2 id: 112129776496
# outer id: 112129777456
# Inner 1 id: 112080297296
# Inner 2 id: 112105531952
# outer id: 112080297296
# Inner 1 id: 112099879552
# Inner 2 id: 112104615568
# outer id: 112099879552
# Inner 1 id: 112097358592
# Inner 2 id: 112105502560
# outer id: 112097358592
# Inner 1 id: 112097361792
# Inner 2 id: 112097361072
# outer id: 112097361792
# Inner 1 id: 112106482704
# Inner 2 id: 112105543440
# outer id: 112106482704
# Inner 1 id: 112100057856
# Inner 2 id: 112100058496
# outer id: 112100057856
# Inner 1 id: 112100058736
# Inner 2 id: 112100059216
# outer id: 112100058736
# Inner 1 id: 112100059136
# Inner 2 id: 112100058016
# outer id: 112100059136
# Inner 1 id: 112100058816
# Inner 2 id: 112100059536
# outer id: 112100058816
# Inner 1 id: 112100047088
# Inner 2 id: 112100048208
# outer id: 112100047088
# Inner 1 id: 112100048768
# Inner 2 id: 112100046048
# outer id: 112100048768
# Inner 1 id: 112050243904
# Inner 2 id: 112100047488
# outer id: 112050243904
# Inner 1 id: 112106229968
# Inner 2 id: 112106230208
# outer id: 112106229968
# Inner 1 id: 112105044368
# Inner 2 id: 112106231968
# outer id: 112105044368
# Inner 1 id: 112139506352
# Inner 2 id: 112099229488
# outer id: 112139506352
# Inner 1 id: 112105906544
# Inner 2 id: 112105710496
# outer id: 112105906544
# Inner 1 id: 112105218576
# Inner 2 id: 112105221856
# outer id: 112105218576
# Inner 1 id: 112099800608
# Inner 2 id: 112099802608
# outer id: 112099800608
# Inner 1 id: 112099241216
# Inner 2 id: 112106838176
# outer id: 112099241216
# Inner 1 id: 112099238176
# Inner 2 id: 112099238976
# outer id: 112099238176
# Inner 1 id: 112097977168
# Inner 2 id: 112097976928
# outer id: 112097977168
# Inner 1 id: 112097978288
# Inner 2 id: 112097978608
# outer id: 112097978288
# Inner 1 id: 112080277952
# Inner 2 id: 112080281392
# outer id: 112080277952
# Inner 1 id: 112099739408
# Inner 2 id: 112131952768
# outer id: 112099739408
# Inner 1 id: 112099428352
# Inner 2 id: 112099426752
# outer id: 112099428352
# Inner 1 id: 112139494944
# Inner 2 id: 112098580160
# outer id: 112139494944
# Inner 1 id: 112104674848
# Inner 2 id: 112104676448
# outer id: 112104674848
# Inner 1 id: 112100016000
# Inner 2 id: 112100013680
# outer id: 112100016000
# Inner 1 id: 112100013120
# Inner 2 id: 112100015440
# outer id: 112100013120
# Inner 1 id: 112100012560
# Inner 2 id: 112100013280
# outer id: 112100012560
# Inner 1 id: 112099293024
# Inner 2 id: 112099294064
# outer id: 112099293024
# Inner 1 id: 112099051360
# Inner 2 id: 112105160096
# outer id: 112099051360
# Inner 1 id: 112099102928
# Inner 2 id: 112099052480
# outer id: 112099102928
# Inner 1 id: 112100056160
# Inner 2 id: 112100054640
# outer id: 112100056160
# Inner 1 id: 112100055440
# Inner 2 id: 112100053120
# outer id: 112100055440
# Inner 1 id: 112100056000
# Inner 2 id: 112100053280
# outer id: 112100056000
# Inner 1 id: 112100053760
# Inner 2 id: 112100056720
# outer id: 112100053760
# Inner 1 id: 112105174800
# Inner 2 id: 112099757712
# outer id: 112105174800
# Inner 1 id: 112106337904
# Inner 2 id: 112099322256
# outer id: 112106337904
# Inner 1 id: 112100021152
# Inner 2 id: 112100022432
# outer id: 112100021152
# Inner 1 id: 112099700288
# Inner 2 id: 112139528272
# outer id: 112099700288
# Inner 1 id: 112099535888
# Inner 2 id: 112097929696
# outer id: 112099535888
# Inner 1 id: 112104986464
# Inner 2 id: 112105891600
# outer id: 112104986464
# Inner 1 id: 112144808816
# Inner 2 id: 112144805936
# outer id: 112144808816
# Inner 1 id: 112099365392
# Inner 2 id: 112105634352
# outer id: 112099365392
# Inner 1 id: 112099339360
# Inner 2 id: 112104653808
# outer id: 112099339360
# Inner 1 id: 112139519760
# Inner 2 id: 112099365392
# outer id: 112139519760
# Inner 1 id: 112100031504
# Inner 2 id: 112100032224
# outer id: 112100031504
# Inner 1 id: 112106849104
# Inner 2 id: 112105114960
# outer id: 112106849104
# Inner 1 id: 112105677168
# Inner 2 id: 112104625456
# outer id: 112105677168
# Inner 1 id: 112144813552
# Inner 2 id: 112099896816
# outer id: 112144813552
# Inner 1 id: 112104763840
# Inner 2 id: 112050530384
# outer id: 112104763840
# Inner 1 id: 112104653808
# Inner 2 id: 112106662368
# outer id: 112104653808
# Inner 1 id: 112099612912
# Inner 2 id: 112099076896
# outer id: 112099612912
# Inner 1 id: 112099365392
# Inner 2 id: 112099367312
# outer id: 112099365392
# Inner 1 id: 112144808816
# Inner 2 id: 112099367872
# outer id: 112144808816
# Inner 1 id: 112106412672
# Inner 2 id: 112099424496
# outer id: 112106412672
# Inner 1 id: 112105892160
# Inner 2 id: 112105893040
# outer id: 112105892160
# Inner 1 id: 112106244656
# Inner 2 id: 112106243216
# outer id: 112106244656
# Inner 1 id: 112099794256
# Inner 2 id: 112097929696
# outer id: 112099794256
# Inner 1 id: 112139528272
# Inner 2 id: 112139528352
# outer id: 112139528272
# Inner 1 id: 112105174800
# Inner 2 id: 112105802288
# outer id: 112105174800
# Inner 1 id: 112100021152
# Inner 2 id: 112099322256
# outer id: 112100021152
# Inner 1 id: 112100021552
# Inner 2 id: 112100024032
# outer id: 112100021552
# Inner 1 id: 112100020672
# Inner 2 id: 112100021312
# outer id: 112100020672
# Inner 1 id: 112106339184
# Inner 2 id: 112106337904
# outer id: 112106339184
# Inner 1 id: 112105701504
# Inner 2 id: 112099757712
# outer id: 112105701504
# Inner 1 id: 112099811120
# Inner 2 id: 112104798688
# outer id: 112099811120
# Inner 1 id: 112100053760
# Inner 2 id: 112050417712
# outer id: 112100053760
# Inner 1 id: 112100054800
# Inner 2 id: 112100055440
# outer id: 112100054800
# Inner 1 id: 112100055920
# Inner 2 id: 112100053840
# outer id: 112100055920
# Inner 1 id: 112100053120
# Inner 2 id: 112100053280
# outer id: 112100053120
# Inner 1 id: 112100056640
# Inner 2 id: 112100055600
# outer id: 112100056640
# Inner 1 id: 112099052480
# Inner 2 id: 112099051360
# outer id: 112099052480
# Inner 1 id: 112104896912
# Inner 2 id: 112104826480
# outer id: 112104896912
# Inner 1 id: 112104895552
# Inner 2 id: 112104897232
# outer id: 112104895552
# Inner 1 id: 112104664240
# Inner 2 id: 112094866608
# outer id: 112104664240
# Inner 1 id: 112100014000
# Inner 2 id: 112100012560
# outer id: 112100014000
# Inner 1 id: 112100014880
# Inner 2 id: 112100013120
# outer id: 112100014880
# Inner 1 id: 112100013680
# Inner 2 id: 112100015200
# outer id: 112100013680
# Inner 1 id: 112104676448
# Inner 2 id: 112104674848
# outer id: 112104676448
# Inner 1 id: 112139497264
# Inner 2 id: 112139494944
# outer id: 112139497264
# Inner 1 id: 112098581680
# Inner 2 id: 112139495264
# outer id: 112098581680
# Inner 1 id: 112099064768
# Inner 2 id: 112099061968
# outer id: 112099064768
# Inner 1 id: 112099738768
# Inner 2 id: 112099739408
# outer id: 112099738768
# Inner 1 id: 112099336960
# Inner 2 id: 112099339360
# outer id: 112099336960
# Inner 1 id: 112099338800
# Inner 2 id: 112099337440
# outer id: 112099338800
# Inner 1 id: 112099336800
# Inner 2 id: 112099479104
# outer id: 112099336800
# Inner 1 id: 112080280592
# Inner 2 id: 112097983104
# outer id: 112080280592
# Inner 1 id: 112100032224
# Inner 2 id: 112100031184
# outer id: 112100032224
# Inner 1 id: 112097976928
# Inner 2 id: 112097979568
# outer id: 112097976928
# Inner 1 id: 112099293664
# Inner 2 id: 112099238176
# outer id: 112099293664
# Inner 1 id: 112099446496
# Inner 2 id: 112139519760
# outer id: 112099446496
# Inner 1 id: 112105196080
# ...
# Inner 1 id: 112099473008
# Inner 2 id: 112105543600
# outer id: 112099473008
# Inner 1 id: 112050418912
# Inner 2 id: 112104607616
# outer id: 112050418912
# Inner 1 id: 112050530384
# Inner 2 id: 112104763840
# outer id: 112050530384
# Inner 1 id: 112100058656
# Inner 2 id: 112100058896
# outer id: 112100058656
# Inner 1 id: 112100059696
# Inner 2 id: 112100057856
# outer id: 112100059696
# Inner 1 id: 112139496864
# Inner 2 id: 112139495264
# outer id: 112139496864
# Inner 1 id: 112099880512
# Inner 2 id: 112099479104
# outer id: 112099880512
# Inner 1 id: 112105176880
# Inner 2 id: 112105531952
# outer id: 112105176880
# Inner 1 id: 112099126208
# Inner 2 id: 112106202016
# outer id: 112099126208
# Inner 1 id: 112099688816
# Inner 2 id: 112099823248
# outer id: 112099688816
# Inner 1 id: 112099640064
# Inner 2 id: 112099102928
# outer id: 112099640064
# Inner 1 id: 112099576528
# Inner 2 id: 112104646176
# outer id: 112099576528
# Inner 1 id: 112080280592
# Inner 2 id: 112099932480
# outer id: 112080280592
# Inner 1 id: 112094866688
# Inner 2 id: 112099238176
# outer id: 112094866688
# Inner 1 id: 112139506352
# Inner 2 id: 112099366192
# outer id: 112139506352
# Inner 1 id: 112099700288
# Inner 2 id: 112104810896
# outer id: 112099700288
# Inner 1 id: 112097325504
# Inner 2 id: 112099102928
# outer id: 112097325504
# Inner 1 id: 112099125168
# Inner 2 id: 112099126208
# outer id: 112099125168
# Inner 1 id: 112099821008
# Inner 2 id: 112104874512
# outer id: 112099821008
# Inner 1 id: 112105272464
# Inner 2 id: 112099823248
# outer id: 112105272464
# Inner 1 id: 112105531952
# Inner 2 id: 112097922304
# outer id: 112105531952
# Inner 1 id: 112106229968
# Inner 2 id: 112106230368
# outer id: 112106229968
# Inner 1 id: 112099613952
# Inner 2 id: 112105407872
# outer id: 112099613952
# Inner 1 id: 112144809216
# Inner 2 id: 112144806496
# outer id: 112144809216
# Inner 1 id: 112139496944
# Inner 2 id: 112139497024
# outer id: 112139496944
# Inner 1 id: 112099473008
# Inner 2 id: 112139493744
# outer id: 112099473008
# Inner 1 id: 112104766480
# Inner 2 id: 112104653808
# outer id: 112104766480
# Inner 1 id: 112100058976
# Inner 2 id: 112100058656
# outer id: 112100058976
# Inner 1 id: 112100058496
# Inner 2 id: 112100057376
# outer id: 112100058496
# Inner 1 id: 112100059136
# Inner 2 id: 112100057856
# outer id: 112100059136
# Inner 1 id: 112100058896
# Inner 2 id: 112100058016
# outer id: 112100058896
# Inner 1 id: 112099076896
# Inner 2 id: 112105457744
# outer id: 112099076896
# Inner 1 id: 112105503520
# Inner 2 id: 112105503280
# outer id: 112105503520
# Inner 1 id: 112105414944
# Inner 2 id: 112105542720
# outer id: 112105414944
# Inner 1 id: 112099291664
# Inner 2 id: 112099292464
# outer id: 112099291664
# Inner 1 id: 112099593152
# Inner 2 id: 112099592032
# outer id: 112099593152
# Inner 1 id: 112104514864
# Inner 2 id: 112099591552
# outer id: 112104514864
# Inner 1 id: 112097361792
# Inner 2 id: 112097359232
# outer id: 112097361792
# Inner 1 id: 112104896912
# Inner 2 id: 112097361072
# outer id: 112104896912
# Inner 1 id: 112106849824
# Inner 2 id: 112104895552
# outer id: 112106849824
# Inner 1 id: 112099429152
# Inner 2 id: 112105802288
# outer id: 112099429152
# Inner 1 id: 112105218976
# Inner 2 id: 112099430272
# outer id: 112105218976
# Inner 1 id: 112144826736
# Inner 2 id: 112144810512
# outer id: 112144826736
# Inner 1 id: 112106483264
# Inner 2 id: 112106480224
# outer id: 112106483264
# Inner 1 id: 112100014000
# Inner 2 id: 112100012080
# outer id: 112100014000
# Inner 1 id: 112100014960
# Inner 2 id: 112100012560
# outer id: 112100014960
# Inner 1 id: 112100016000
# Inner 2 id: 112100013680
# outer id: 112100016000
# Inner 1 id: 112104664880
# Inner 2 id: 112104663120
# outer id: 112104664880
# Inner 1 id: 112105377920
# Inner 2 id: 112104664320
# outer id: 112105377920
# Inner 1 id: 112099757712
# Inner 2 id: 112099229488
# outer id: 112099757712
# Inner 1 id: 112105194640
# Inner 2 id: 112105194800
# outer id: 112105194640
# Inner 1 id: 112100047888
# Inner 2 id: 112100047488
# outer id: 112100047888
# Inner 1 id: 112100048768
# Inner 2 id: 112105621264
# outer id: 112100048768
# Inner 1 id: 112099337440
# Inner 2 id: 112099336400
# outer id: 112099337440
# Inner 1 id: 112099336560
# Inner 2 id: 112099337600
# outer id: 112099336560
# Inner 1 id: 112105657168
# Inner 2 id: 112100031184
# outer id: 112105657168
# Inner 1 id: 112099931920
# Inner 2 id: 112099930640
# outer id: 112099931920
# Inner 1 id: 112106339184
# Inner 2 id: 112097982944
# outer id: 112106339184
# Inner 1 id: 112105493968
# Inner 2 id: 112099241536
# outer id: 112105493968
# Inner 1 id: 112098580400
# Inner 2 id: 112105974800
# outer id: 112098580400
# Inner 1 id: 112144794848
# Inner 2 id: 112144795888
# outer id: 112144794848
# Inner 1 id: 112104674528
# Inner 2 id: 112105890240
# outer id: 112104674528
# Inner 1 id: 112097978288
# Inner 2 id: 112097979568
# outer id: 112097978288
# Inner 1 id: 112099052480
# Inner 2 id: 112099053280
# outer id: 112099052480
# Inner 1 id: 112105160096
# Inner 2 id: 112099535488
# outer id: 112105160096
# Inner 1 id: 112099802128
# Inner 2 id: 112099489232
# outer id: 112099802128
# Inner 1 id: 112105635312
# Inner 2 id: 112104826480
# outer id: 112105635312
# Inner 1 id: 112097976928
# Inner 2 id: 112097977168
# outer id: 112097976928
# Inner 1 id: 112105891600
# Inner 2 id: 112105893040
# outer id: 112105891600
# Inner 1 id: 112104626416
# Inner 2 id: 112104625456
# outer id: 112104626416
# Inner 1 id: 112144794848
# Inner 2 id: 112104674528
# outer id: 112144794848
# Inner 1 id: 112139519200
# Inner 2 id: 112139521600
# outer id: 112139519200
# Inner 1 id: 112099436704
# Inner 2 id: 112097407184
# outer id: 112099436704
# Inner 1 id: 112098580160
# Inner 2 id: 112098579680
# outer id: 112098580160
# Inner 1 id: 112105494448
# Inner 2 id: 112105493968
# outer id: 112105494448
# Inner 1 id: 112097928496
# Inner 2 id: 112097929696
# outer id: 112097928496
# Inner 1 id: 112094866768
# Inner 2 id: 112094866688
# outer id: 112094866768
# Inner 1 id: 112100029904
# Inner 2 id: 112100028624
# outer id: 112100029904
# Inner 1 id: 112104646176
# Inner 2 id: 112104646976
# outer id: 112104646176
# Inner 1 id: 112099757712
# Inner 2 id: 112099061968
# outer id: 112099757712
# Inner 1 id: 112099338480
# Inner 2 id: 112099337760
# outer id: 112099338480
# Inner 1 id: 112099338720
# Inner 2 id: 112099337600
# outer id: 112099338720
# Inner 1 id: 112099336400
# Inner 2 id: 112099339440
# outer id: 112099336400
# Inner 1 id: 112139507312
# Inner 2 id: 112099336960
# outer id: 112139507312
# Inner 1 id: 112099240656
# Inner 2 id: 112099241216
# outer id: 112099240656
# Inner 1 id: 112104031536
# Inner 2 id: 112099238816
# outer id: 112104031536
# Inner 1 id: 112100045968
# Inner 2 id: 112100047888
# outer id: 112100045968
# Inner 1 id: 112100048208
# Inner 2 id: 112100045728
# outer id: 112100048208
# Inner 1 id: 112105194640
# Inner 2 id: 112100047488
# outer id: 112105194640
# Inner 1 id: 112099226928
# Inner 2 id: 112099712096
# outer id: 112099226928
# Inner 1 id: 112106243216
# Inner 2 id: 112106245456
# outer id: 112106243216
# Inner 1 id: 112104663120
# Inner 2 id: 112104664320
# outer id: 112104663120
# Inner 1 id: 112100016000
# Inner 2 id: 112100014160
# outer id: 112100016000
# Inner 1 id: 112100015520
# Inner 2 id: 112100014960
# outer id: 112100015520
# Inner 1 id: 112100015200
# Inner 2 id: 112100014400
# outer id: 112100015200
# Inner 1 id: 112105906544
# Inner 2 id: 112105908144
# outer id: 112105906544
# Inner 1 id: 112144827056
# Inner 2 id: 112106483264
# outer id: 112144827056
# Inner 1 id: 112099799328
# Inner 2 id: 112099802128
# outer id: 112099799328
# Inner 1 id: 112099930640
# Inner 2 id: 112099932480
# outer id: 112099930640
# Inner 1 id: 112105218576
# Inner 2 id: 112105218976
# outer id: 112105218576
# Inner 1 id: 112099426752
# Inner 2 id: 112099428032
# outer id: 112099426752
# Inner 1 id: 112104514864
# Inner 2 id: 112104517104
# outer id: 112104514864
# Inner 1 id: 112104895552
# Inner 2 id: 112103866896
# outer id: 112104895552
# Inner 1 id: 112106337904
# Inner 2 id: 112097361792
# outer id: 112106337904
# Inner 1 id: 112099593152
# Inner 2 id: 112099592032
# outer id: 112099593152
# Inner 1 id: 112099291664
# Inner 2 id: 112099292464
# outer id: 112099291664
# Inner 1 id: 112105542720
# Inner 2 id: 112099895056
# outer id: 112105542720
# Inner 1 id: 112105455984
# Inner 2 id: 112100059216
# outer id: 112105455984
# Inner 1 id: 112100061056
# Inner 2 id: 112100058096
# outer id: 112100061056
# Inner 1 id: 112050530384
# Inner 2 id: 112139496224
# outer id: 112050530384
# Inner 1 id: 112144805936
# Inner 2 id: 112105407872
# outer id: 112144805936
# Inner 1 id: 112106230368
# Inner 2 id: 112105472128
# outer id: 112106230368
# Inner 1 id: 112099807280
# Inner 2 id: 112104443216
# outer id: 112099807280
# Inner 1 id: 112105701504
# Inner 2 id: 112099050640
# outer id: 112105701504
# Inner 1 id: 112104874512
# Inner 2 id: 112099446496
# outer id: 112104874512
# Inner 1 id: 112144805936
# Inner 2 id: 112097922864
# outer id: 112144805936
# Inner 1 id: 112105455984
# Inner 2 id: 112104653808
# outer id: 112105455984
# Inner 1 id: 112100061056
# Inner 2 id: 112105542720
# outer id: 112100061056
# Inner 1 id: 112100060496
# Inner 2 id: 112100059696
# outer id: 112100060496
# Inner 1 id: 112100058016
# Inner 2 id: 112100058096
# outer id: 112100058016
# Inner 1 id: 112099076896
# Inner 2 id: 112099895056
# outer id: 112099076896
# Inner 1 id: 112099291664
# Inner 2 id: 112105503280
# outer id: 112099291664
# Inner 1 id: 112099292464
# Inner 2 id: 112099292304
# outer id: 112099292464
# Inner 1 id: 112099888144
# Inner 2 id: 112105509392
# outer id: 112099888144
# Inner 1 id: 112104895552
# Inner 2 id: 112131953088
# outer id: 112104895552
# Inner 1 id: 112099575968
# Inner 2 id: 112099322256
# outer id: 112099575968
# Inner 1 id: 112104517104
# Inner 2 id: 112104514864
# outer id: 112104517104
# Inner 1 id: 112098994976
# Inner 2 id: 112105802288
# outer id: 112098994976
# Inner 1 id: 112099430272
# Inner 2 id: 112099426752
# outer id: 112099430272
# Inner 1 id: 112105221856
# Inner 2 id: 112105218976
# outer id: 112105221856
# Inner 1 id: 112099933360
# Inner 2 id: 112099930640
# outer id: 112099933360
# Inner 1 id: 112144810512
# Inner 2 id: 112144813552
# outer id: 112144810512
# Inner 1 id: 112099802128
# Inner 2 id: 112099799328
# outer id: 112099802128
# Inner 1 id: 112144827216
# Inner 2 id: 112144826736
# outer id: 112144827216
# Inner 1 id: 112106483264
# Inner 2 id: 112106480944
# outer id: 112106483264
# Inner 1 id: 112105906544
# Inner 2 id: 112105909184
# outer id: 112105906544
# Inner 1 id: 112099879552
# Inner 2 id: 112104825840
# outer id: 112099879552
# Inner 1 id: 112100015200
# Inner 2 id: 112099700288
# outer id: 112100015200
# Inner 1 id: 112100015440
# Inner 2 id: 112100013280
# outer id: 112100015440
# Inner 1 id: 112100014960
# Inner 2 id: 112100012560
# outer id: 112100014960
# Inner 1 id: 112080214976
# Inner 2 id: 112100013120
# outer id: 112080214976
# Inner 1 id: 112097359232
# Inner 2 id: 112097358592
# outer id: 112097359232
# Inner 1 id: 112097361792
# Inner 2 id: 112097358992
# outer id: 112097361792
# Inner 1 id: 112104664320
# Inner 2 id: 112104664240
# outer id: 112104664320
# Inner 1 id: 112105736592
# Inner 2 id: 112106245456
# outer id: 112105736592
# Inner 1 id: 112099226928
# Inner 2 id: 112106852144
# outer id: 112099226928
# Inner 1 id: 112099125168
# Inner 2 id: 112099126208
# outer id: 112099125168
# Inner 1 id: 112105194800
# Inner 2 id: 112105194640
# outer id: 112105194800
# Inner 1 id: 112106339184
# Inner 2 id: 112106336304
# outer id: 112106339184
# Inner 1 id: 112105409072
# Inner 2 id: 112105407872
# outer id: 112105409072
# Inner 1 id: 112139507312
# Inner 2 id: 112139506352
# outer id: 112139507312
# Inner 1 id: 112139494944
# Inner 2 id: 112139497264
# outer id: 112139494944
# Inner 1 id: 112100048048
# Inner 2 id: 112100045888
# outer id: 112100048048
# Inner 1 id: 112098665296
# Inner 2 id: 112105272464
# outer id: 112098665296
# Inner 1 id: 112105377920
# Inner 2 id: 112105485696
# outer id: 112105377920
# Inner 1 id: 112099336800
# Inner 2 id: 112099339360
# outer id: 112099336800
# Inner 1 id: 112105621264
# Inner 2 id: 112104648096
# outer id: 112105621264
# Inner 1 id: 112100029504
# Inner 2 id: 112094866688
# outer id: 112100029504
# Inner 1 id: 112105493968
# Inner 2 id: 112098581680
# outer id: 112105493968
# Inner 1 id: 112139520880
# Inner 2 id: 112144795888
# outer id: 112139520880
# Inner 1 id: 112139527952
# Inner 2 id: 112099195200
# outer id: 112139527952
# Inner 1 id: 112106232928
# Inner 2 id: 112099052480
# outer id: 112106232928
# Inner 1 id: 112100020352
# Inner 2 id: 112100021152
# outer id: 112100020352
# Inner 1 id: 112105621264
# Inner 2 id: 112097929696
# outer id: 112105621264
# Inner 1 id: 112098581680
# Inner 2 id: 112098580400
# outer id: 112098581680
# Inner 1 id: 112099631632
# Inner 2 id: 112105377920
# outer id: 112099631632
# Inner 1 id: 112100031264
# Inner 2 id: 112100029504
# outer id: 112100031264
# Inner 1 id: 112104645616
# Inner 2 id: 112104646976
# outer id: 112104645616
# Inner 1 id: 112105485696
# Inner 2 id: 112105485296
# outer id: 112105485696
# Inner 1 id: 112099238416
# Inner 2 id: 112099238176
# outer id: 112099238416
# Inner 1 id: 112105710496
# Inner 2 id: 112099238816
# outer id: 112105710496
# Inner 1 id: 112100048048
# Inner 2 id: 112099053280
# outer id: 112100048048
# Inner 1 id: 112100045728
# Inner 2 id: 112100044928
# outer id: 112100045728
# Inner 1 id: 112099762704
# Inner 2 id: 112100045888
# outer id: 112099762704
# Inner 1 id: 112105792176
# Inner 2 id: 112099102928
# outer id: 112105792176
# Inner 1 id: 112099821008
# Inner 2 id: 112099823248
# outer id: 112099821008
# Inner 1 id: 112105409072
# Inner 2 id: 112099488192
# outer id: 112105409072
# Inner 1 id: 112106336304
# Inner 2 id: 112106339184
# outer id: 112106336304
# Inner 1 id: 112105194800
# Inner 2 id: 112105196080
# outer id: 112105194800
# Inner 1 id: 112099712096
# Inner 2 id: 112099712896
# outer id: 112099712096
# Inner 1 id: 112104676448
# Inner 2 id: 112104674528
# outer id: 112104676448
# Inner 1 id: 112099229088
# Inner 2 id: 112099229488
# outer id: 112099229088
# Inner 1 id: 112106245456
# Inner 2 id: 112106849104
# outer id: 112106245456
# Inner 1 id: 112105634352
# Inner 2 id: 112105631872
# outer id: 112105634352
# Inner 1 id: 112139496864
# Inner 2 id: 112139496224
# outer id: 112139496864
# Inner 1 id: 112104664240
# Inner 2 id: 112104664880
# outer id: 112104664240
# Inner 1 id: 112097978128
# Inner 2 id: 112097977168
# outer id: 112097978128
# Inner 1 id: 112097360912
# Inner 2 id: 112097325504
# outer id: 112097360912
# Inner 1 id: 112097358352
# Inner 2 id: 112097358992
# outer id: 112097358352
# Inner 1 id: 112104614848
# Inner 2 id: 112104613248
# outer id: 112104614848
# Inner 1 id: 112100014960
# Inner 2 id: 112104766480
# outer id: 112100014960
# Inner 1 id: 112100013120
# Inner 2 id: 112100015200
# outer id: 112100013120
# Inner 1 id: 112100015680
# Inner 2 id: 112100014160
# outer id: 112100015680
# Inner 1 id: 112105974800
# Inner 2 id: 112100014400
# outer id: 112105974800
# Inner 1 id: 112104825840
# Inner 2 id: 112104826480
# outer id: 112104825840
# Inner 1 id: 112099879552
# Inner 2 id: 112144797328
# outer id: 112099879552
# Inner 1 id: 112105906624
# Inner 2 id: 112105909184
# outer id: 112105906624
# Inner 1 id: 112050418352
# Inner 2 id: 112050417712
# outer id: 112050418352
# Inner 1 id: 112106480224
# Inner 2 id: 112106483264
# outer id: 112106480224
# Inner 1 id: 112099809520
# Inner 2 id: 112099811120
# outer id: 112099809520
# Inner 1 id: 112099339440
# Inner 2 id: 112099336560
# outer id: 112099339440
# Inner 1 id: 112099339360
# Inner 2 id: 112099336400
# outer id: 112099339360
# Inner 1 id: 112105893040
# Inner 2 id: 112105891600
# outer id: 112105893040
# Inner 1 id: 112099931200
# Inner 2 id: 112099930640
# outer id: 112099931200
# Inner 1 id: 112105218976
# Inner 2 id: 112099428352
# outer id: 112105218976
# Inner 1 id: 112106465680
# Inner 2 id: 112099576528
# outer id: 112106465680
# Inner 1 id: 112099592032
# Inner 2 id: 112105509392
# outer id: 112099592032
# Inner 1 id: 112105218576
# Inner 2 id: 112098995056
# outer id: 112105218576
# Inner 1 id: 112105802608
# Inner 2 id: 112105802288
# outer id: 112105802608
# Inner 1 id: 112106613696
# Inner 2 id: 112144810512
# outer id: 112106613696
# Inner 1 id: 112099931920
# Inner 2 id: 112099931440
# outer id: 112099931920
# Inner 1 id: 112105890320
# Inner 2 id: 112105893040
# outer id: 112105890320
# Inner 1 id: 112105531952
# Inner 2 id: 112106834400
# outer id: 112105531952
# Inner 1 id: 112099807920
# Inner 2 id: 112099809520
# outer id: 112099807920
# Inner 1 id: 112099611232
# Inner 2 id: 112099612912
# outer id: 112099611232
# Inner 1 id: 112099774512
# Inner 2 id: 112099613952
# outer id: 112099774512
# Inner 1 id: 112139519760
# Inner 2 id: 112139519200
# outer id: 112139519760
# Inner 1 id: 112131953088
# Inner 2 id: 112099424496
# outer id: 112131953088
# Inner 1 id: 112105908144
# Inner 2 id: 112105906624
# outer id: 112105908144

# %%
w
# Out:
# array([-2.        ,  1.567752  , -1.0663645 ,  1.8937115 ,  2.54472475])

# %%
t
# Out:
# 40

# %% [markdown]
# With learning rate $\eta=0.5$, the average number of updates is 40.

# %% [markdown]
# ## Question 18

# %% [markdown]
# Next, we play with the pocket algorithm. Modify your PLA in Question 16 to visit examples purely randomly, and then add the 'pocket' steps to the algorithm. We will use `hw1_18_train.dat` as the training data set $\mathcal{D}$ and `hw1_18_test.dat` as test set for verifying the g returned by your algorithm (see lecture 4 about verifying). The sets are of the same format as the previous one. Run the pocket algorithm with a total of 50 updates on $\mathcal{D}$, and verify the performance of $\mathbf{w}_{\text{POCKET}}$ using the test set. Please repeat your experiment for 2000 times, each with a different random seed. What is the average error rate on the test set?

# %%
# Load data
train_data = pd.read_csv('hw1_18_train.dat', sep='\s+', header=None, names=['x1', 'x2', 'x3', 'x4', 'y'])
test_data = pd.read_csv('hw1_18_test.dat', sep='\s+', header=None, names=['x1', 'x2', 'x3', 'x4', 'y'])

# Construct features and labels
y_train = train_data['y'].to_numpy()
X_train = train_data[['x1', 'x2', 'x3', 'x4']].to_numpy()

y_test = test_data['y'].to_numpy()
X_test = test_data[['x1', 'x2', 'x3', 'x4']].to_numpy()

# %%
def PLA_pocket(X, y, num_update=50):
    """
    Modified PLA algorithm by keeping best weights in pocket.
    
    Args:
        X         : numpy array(n, d), feature matrix
        y         : numpy array(n, ), labels
        num_update: int, number of updates of w_pocket to run on the data set
    
    Returns:
        w_pocket: numpy array(d + 1, ), best weights including bias w0
    """
    
    n, d = X.shape
    # Add a column of ones as first column
    X = np.c_[np.ones((n, 1)), X]
    
    # Initialize w to 0 and add an extra zero for w0
    w = np.zeros(d + 1)
    w_pocket = np.zeros(d + 1)
    
    smallest_error_rate = 1.0
    update_cnt = 0
    t = 0
    correct_num = 0
    
    while update_cnt < num_update and correct_num < n:
        x_t, y_t = X[t], y[t]
        if sign(w.T @ x_t) == y_t:
            correct_num += 1
        else:
            w += y_t * x_t
            update_cnt += 1
            correct_num = 0
            current_error_rate = error_rate(X, y, w)
            if current_error_rate < smallest_error_rate:
                w_pocket = w.copy()  #### NOTE: DO NOT write w_pocket=w directly, otherwise, w_pocket and w will point to the object
                smallest_error_rate = current_error_rate
        if t == n - 1:
            t = 0
        else:
            t += 1   
            
    return w_pocket


################ Helper functions ################

# Vectorized version of sign function
sign_vec = np.vectorize(sign)


def error_rate(X, y, w):
    """
    Calculate the current error rate with the given weights w and examples (X, y).
    
    Returns:
        err: double, error rate 
    Argss
        X: numpy array(n, d + 1), feature matrix including a column of ones as first column
        y: numpy array(n, ), labels
        w: numpy array(d + 1, ), current weight
    """
    
    n = y.shape[0]
    err = np.sum(sign_vec(X @ w) != y) / n
    
    return err

# %% [markdown]
# **Note:** the correct step `w_pocket = w.copy()` instead of `w_pocket = w` is where I made a mistake when implementing the algorithm and I took a lot of time before identifying the bug.

# %%
def PLA_pocket_test_random(X_train, y_train, X_test, y_test, num_updates=50):
    """
    Train PLA by pocket algorithm using trainning set and test on test set. 
    Repeat experiment for 2000 times and return average error rate.
    
    Note: we visit examples purely randomly
    
    Args:
        X_train    : numpy array(n, d), training feature matrix
        y_train    : numpy array(n, ), training labels
        X_test     : numpy array(m, d), test feature matrix
        y_test     : numpy array(m, ), test labels
        num_updates: int, number of updates of pocket weights to run on the data set
    Returns:
        avg_error: the average of error rate
    """

    n = X_test.shape[0]
    X_test = np.c_[np.ones((n, 1)), X_test]

    T = 2000
    indices = np.arange(n) 
    total_error = 0.0

    for i in range(T):
        np.random.shuffle(indices)  
        X_train = X_train[indices]
        y_train = y_train[indices]
        w = PLA_pocket(X_train, y_train, num_updates)
        error = error_rate(X_test, y_test, w)
#         print("error on test set:", error)
        total_error += error
        
    avg_error = total_error / T
    
    return avg_error

# %%
PLA_pocket_test_random(X_train, y_train, X_test, y_test, 50)
# Out:
# 0.13146899999999967

# %% [markdown]
# The average error rate on the test set is about 0.13 on my computer.

# %% [markdown]
# ## Question 19

# %% [markdown]
# Modify your algorithm in Question 18 to return $\mathbf{w}_{50}$ (the PLA vector after 50 updates) instead of $\hat{\mathbf{w}}$ (the pocket vector) after 50 updates. Run the modified algorithm on $\mathcal{D}$, and verify the performance using the test set. Please repeat your experiment for 2000 times, each with a different random seed. What is the average error rate on the test set?

# %%
def PLA_fixed_updates_test_random(X_train, y_train, X_test, y_test, num_update):
    """
    Train PLA by pocket algorithm using trainning set and test on test set. 
    Repeat experiment for 2000 times and return average error rate.
    
    Note: we visit examples purely randomly
    
    Args:
        X_train   : numpy array(n, d), training feature matrix
        y_train   : numpy array(n, ), training labels
        X_test    : numpy array(m, d), test feature matrix
        y_test    : numpy array(m, ), test labels
        num_update: int, number of updates of weights to run on the data set
    Returns:
        avg_error: the average of error rate
    """

    n = X_test.shape[0]
    X_test = np.c_[np.ones((n, 1)), X_test]

    T = 2000
    indices = np.arange(n) 
    total_error = 0.0

    for i in range(T):
        np.random.shuffle(indices)  
        X_train = X_train[indices]
        y_train = y_train[indices]
        w = PLA_fixed_updates(X_train, y_train, num_update)
        error = error_rate(X_test, y_test, w)
#         print("error on test set:", error)
        total_error += error
        

    avg_error = total_error / T
    return avg_error


def PLA_fixed_updates(X, y, num_update=50):
    """
    Returns the weights after the required number of updates.
    
    Args:
        X         : numpy array(n, d), feature matrix
        y         : numpy array(n, ), labels
        num_update: int, number of updates of weights to run on the data set
    
    Returns:
        w: numpy array(d + 1, ), weights(including bias w0) after the required number of updates
    """
    
    n, d = X.shape
    # Add a column of ones as first column
    X = np.c_[np.ones((n, 1)), X]
    
    # Initialize w to 0 and add an extra zero for w0
    w = np.zeros(d + 1)
    
    update_cnt = 0
    t = 0
    correct_num = 0
    
    while update_cnt < num_update and correct_num < n:
        x_t, y_t = X[t], y[t]
        if sign(w.T @ x_t) == y_t:
            correct_num += 1
        else:
            w += y_t * x_t
            update_cnt += 1
            correct_num = 0
        if t == n - 1:
            t = 0
        else:
            t += 1   
            
    return w

# %%
PLA_fixed_updates_test_random(X_train, y_train, X_test, y_test, 50)
# Out:
# 0.36959099999999995

# %% [markdown]
# The average error on the test set is about 0.37.

# %% [markdown]
# ## Question 20

# %% [markdown]
# Modify your algorithm in Question 18 to run for 100 updates instead of 50, and verify the performance of $\mathbf{w}_{\text{POCKET}}$ using the test set. Please repeat your experiment for 2000 times, each with a different random seed. What is the average error rate on the test set?

# %%
PLA_pocket_test_random(X_train, y_train, X_test, y_test, 100)
# Out:
# 0.11417099999999998

# %% [markdown]
# The average error rate on the test set is about 0.11.
